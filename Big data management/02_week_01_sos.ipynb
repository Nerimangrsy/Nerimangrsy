# %% [markdown]
# # INTRODUCTION TO SQL ON POSTGRESQL SERVER

# %% [markdown]
# **BY SERHAT ÇEVİKEL**

# %% [markdown]
# In today's session, we will be continuing from where we left:
#
# - We explored the data
# - We transformed the data
# - Now we will start the postgresql daemon
# - Create a database
# - Import data into it
# - Start querying the database

# %% [markdown]
# For simplicity purposes and due to time/resource constraints, we will import and set primary keys on only selected few tables
#
# We will skip the melting of tables, a task for which we provided an example before
#
# We already have a complete working database as imdb2
#
# First as we did before, we unzip the gzipped tsv files and trim the header rows, since PostgreSQL do not allow for header rows while importing tsv files according to [its own documentation on the COPY Command](https://www.postgresql.org/docs/current/static/sql-copy.html)
#
# >HEADER
#
# >    Specifies that the file contains a header line with the names of each column in the file. On output, the first line contains the column names from the table, and on input, the first line is ignored. This option is allowed only when using CSV format.
#
#
# One option might be to convert a tsv into a csv by translating tab characters to commas using "sed" or better "tr". We will also use this option for selected tables

# %% [markdown]
# ## From the shell to PostgreSQL

# %% [markdown]
# ### Start the postgresql daemon on the background

# %% [markdown]
# Since that may take some time between 5-10 minutes in our binder environment, it is better that we do it now, so that we can proceed with file operations without waiting for the daemon to start:

# %%
sudo service postgresql start
# Out:
# Starting PostgreSQL 11 database server: main.

# %% [markdown]
# If an error is returned, you should rerun the cell.

# %% [markdown]
# We can check whether the daemon has started with:

# %%
psql -U postgres -c "\l"
# Out:
#                               List of databases
#    Name    |  Owner   | Encoding | Collate |  Ctype  |   Access privileges
# -----------+----------+----------+---------+---------+-----------------------
#  imdb2     | postgres | UTF8     | C.UTF-8 | C.UTF-8 |
#  postgres  | postgres | UTF8     | C.UTF-8 | C.UTF-8 |
#  template0 | postgres | UTF8     | C.UTF-8 | C.UTF-8 | =c/postgres          +
#            |          |          |         |         | postgres=CTc/postgres
#  template1 | postgres | UTF8     | C.UTF-8 | C.UTF-8 | =c/postgres          +
#            |          |          |         |         | postgres=CTc/postgres
#  world     | postgres | UTF8     | C.UTF-8 | C.UTF-8 |
# (5 rows)

# %% [markdown]
# This will list all databases on our server

# %% [markdown]
# Until this command returns something successfully, the PostgreSQL server will not respond.
#
# But until we reach 1.2, we do not need to connect to the PostgreSQL server.

# %% [markdown]
# ### Environment variables

# %% [markdown]
# First, declare the environment variables for paths

# %%
datadir=~/data
imdbdir=$datadir/imdb

# %% [markdown]
# ### Unzip the gzipped files and trim headers

# %% [markdown]
# Then create the directory for unzipped files:

# %%
mkdir -p $imdbdir/tsv2

# %% [markdown]
# And unzip the files if they do not exist yet:

# %%
find $imdbdir/tsv -mindepth 1 | \
    parallel -k -j0 "basenm=\$(basename {});
        if [ ! -e ${imdbdir}/tsv2/\${basenm%.gz} ];
        then
            gunzip -c {} > \
            ${imdbdir}/tsv2/\${basenm%.gz};
        fi
        "

# %% [markdown]
# the "basename" function extracts the filename portion from the full path name so we can reproduce the full path name under another directory

# %%
tldr basename

# %% [markdown]
# The ```${basenm%.gz}``` portion is a form of "parameter substitution"
#
# It means:
#
# > \\${var%Pattern}, \\${var%%Pattern}
#
# > \\${var%Pattern} Remove from \\$var the shortest part of \\$Pattern that matches the back end of \\$var.
#
#
# > \\${var%%Pattern} Remove from \\$var the longest part of \\$Pattern that matches the back end of \\$var.
#
# (https://www.tldp.org/LDP/abs/html/parameter-substitution.html)

# %% [markdown]
# Now let's check whether the gunzipped files are there:

# %%
ls -l $imdbdir/tsv2

# %% [markdown]
# Now we will trim the first lines and dump into a new directory named tsv3.

# %%
mkdir -p $imdbdir/tsv3

# %%
find $imdbdir/tsv2 -mindepth 1 | \
    parallel -k -j0 "basenm=\$(basename {});
        if [ ! -e ${imdbdir}/tsv3/\${basenm/.tsv/2.tsv} ];
        then
            tail -n+2 {} > \
            ${imdbdir}/tsv3/\${basenm/.tsv/2.tsv};
        fi
        "

# %% [markdown]
# "basenm/.tsv/2.tsv" part is like the substitution command of sed: find ".tsv" and replace with "2.tsv"
#
# "-e" checks the existence of the file and proceeds only if the file does not exist yet

# %% [markdown]
# Check whether row counts are decremented:

# %%
find $imdbdir/tsv2 -mindepth 1 | \
    parallel -k -j0 "basenm=\$(basename {});
        {
            printf '%s\t' \$basenm;
            cat $imdbdir/tsv2/\$basenm | wc -l;
            cat $imdbdir/tsv3/\${basenm/.tsv/2.tsv} | wc -l;
        } | tr '\n' '\t' | xargs echo -e
        " | column -t

# %% [markdown]
# ### Convert tsv's to csv's

# %% [markdown]
# Now let's convert tsv's to csv's

# %%
mkdir -p $imdbdir/csv

# %%
find $imdbdir/tsv2 -mindepth 1 | \
    parallel -k -j0 "basenm=\$(basename {});
        if [ ! -e ${imdbdir}/csv/\${basenm/.tsv/.csv} ];
        then
            cat {} | tr '\t' ',' > \
            ${imdbdir}/csv/\${basenm/.tsv/.csv};
        fi
        "

# %% [markdown]
# List the csv directory

# %%
ls -l $imdbdir/csv

# %% [markdown]
# And view the head of a file with column command, with "," as the separator/delimiter character:

# %%
head $imdbdir/csv/name.basics.csv | column -t -s ","

# %% [markdown]
# We can also use the csv files to create the database

# %% [markdown]
# ### Ways to access the postgresql server

# %% [markdown]
# Remember we probed whether postgresql server is listening by:

# %%
psql -U postgres -c "\l"

# %% [markdown]
# psql is the built-in interactive terminal client for PostgreSQL. It can both be used interactively with it shell or non-interactively with the "-c" (command) flag as we used above

# %%
tldr psql

# %% [markdown]
# psql is good for embedding sql codes in shell scripts. However for interactive purposes, it does not provide much features.
#
# A better option is the "pgcli" interface. It is a part of the dbcli project, that provides better command line interfaces (CLI) as DBclients:
#
# https://github.com/dbcli/pgcli
#
# https://www.pgcli.com/

# %% [markdown]
# First we open a new terminal window:

# %%
last=$(( $(ps aux | awk -F " " '$7 ~ /pts/ { print $7 }' | grep -Po "\d+" | sort -nu | tail -1) + 1 ))
echo $last

# %%
echo "Follow the working one of the following links to open a terminal: (that matches the domain of the URL above)"
echo "https://hub.gke.mybinder.org/user/serhatcevikel-bdm_2019-$(hostname | grep -Po '(?<=2019-2d).*?$')/terminals/$last"
echo "https://hub-binder.mybinder.ovh/user/serhatcevikel-bdm_2019-$(hostname | grep -Po '(?<=2019-2d).*?$')/terminals/$last"
echo "https://notebooks.gesis.org/binder/jupyter/user/serhatcevikel-bdm_2019-$(hostname | grep -Po '(?<=2019-2d).*?$')/terminals/$last"

# %% [markdown]
# Now please copy and paste the below command inside that terminal:
#
# ```Bash
# screen -S 1
# ```

# %%
scr=$(screen -ls | grep -P "Attached" | head -1 | grep -Po "^\t+.+?(?=\s|\t)" | tr -d "\t")
screen -S $scr -X stuff "pgcli -U postgres\n"

# %% [markdown]
# Some options are automatically selected at build time.
#
# - Auto completion is on
# - Multiline mode is on: Statements canbe multiline, to execute them, put a semi-colon ";" at the end
# - Vi-mode is on: If you are fluent at using vim editor, the same key bindings apply now

# %% [markdown]
# We may be using other interfaces, and here we will prefer to execute our commands through the Jupyter notebook. However, it is better to have pgcli opened on the terminal, since the smart completion facility makes it easier to write SQL statements. You can copy the statement to the Jupyter cells to be executed

# %% [markdown]
# Another client is pgAdmin4. It had a GUI interface before, but now it only works on web mode, hosted by your web browser - just as Jupyter is.
#
# Due to limitations of the binder environment, we won't be using pgAdmin4 but you can check it from https://www.pgadmin.org/

# %% [markdown]
# There are several ways to access postgresql server from the Jupyter:
#
# - Use bash kernel and send SQL commands via the "-c" flag of psql client
# - Use SQL kernel of the beakerx project
# - Use sql magic of python kernel through ipython_sql extension
# - Use postgres_kernel
# - Use any of the kernels through SoS kernel which is polyglot - each cell can be run on a separate kernel, which we do now

# %% [markdown]
# SQL kernel of beakerx extension is the most visually appealing and easy to use one, when used as a stand-alone notebook. However it does not play well from inside an SoS notebook, and we prefer the "polyglot" nature of the SoS notebook
#
# postgres_kernel is buggy
#
# So we will either use the sql magic on Python3 kernel or psql in non-interactive mode on bash_kernel

# %% [markdown]
# ## Create a table space and a database

# %% [markdown]
# For the rest of the commands to work, PostgreSQL server should be listening on port 5432. Let's check:

# %%
psql -U postgres -c "\l"

# %% [markdown]
# If the command does not list  the existing databases, we wait until it does so by re-running the cell.
#
# Hopefully, we started the database daemon back in the beginning of the session.

# %% [markdown]
# First we will create a tablespace - a directory on the filesystem for the PostgreSQL server to store our new database:
#
#
# >22.6. Tablespaces
# >
# >Tablespaces in PostgreSQL allow database administrators to define locations in the file system where the files representing database objects can be stored. Once created, a tablespace can be referred to by name when creating database objects.
# >
# >By using tablespaces, an administrator can control the disk layout of a PostgreSQL installation. This is useful in at least two ways. First, if the partition or volume on which the cluster was initialized runs out of space and cannot be extended, a tablespace can be created on a different partition and used until the system can be reconfigured.
#
# (https://www.postgresql.org/docs/current/static/manage-ag-tablespaces.html)

# %% [markdown]
# Create a directory on the filesystem:

# %%
sudo mkdir -p /pg1

# %% [markdown]
# Check the user and group ownership with the stat command:

# %%
stat -c "%U %G" /pg1

# %%
tldr stat

# %% [markdown]
# And make it owned by postgres user:

# %%
sudo chown -R postgres:postgres /pg1

# %% [markdown]
# And check again:

# %%
stat -c "%U %G" /pg1

# %% [markdown]
# Note that, in this binder image, sudoer (admin) jovyan user becomes sudo without password prompt. This is for the non-interactive feature of bash_kernel on Jupyter (it cannot prompt for a password) and for better scriptability.
#
# This environment is a short lived container isolated from the rest of the operating system it sits atop. This feature should not be done in a production environment

# %% [markdown]
# Let's check again whether our postgresql server responds to our requests:

# %% [markdown]
# Now it is time to create a tablespace on /pg location and create a database there:

# %% [markdown]
# Let's review the list of databases again:

# %%
psql -U postgres -c "\l"

# %% [markdown]
# First let's enable the sql magic on python kernel, so that we can send SQL commands to the PostgreSQL server easily with minimal additional syntax (using psql from the bash is another option):

# %%
%load_ext sql

# %% [markdown]
# And create a connection with our server into the maintenance database "postgres":

# %%
%sql postgres://postgres@localhost/postgres

# %% [markdown]
# Now from inside the Python3 kernel, we can execute sql statements easily if we insert a "%%sql" magic in the first line as such:
#
# Comments start with "--"
#
# Statements end with ";"

# %% [markdown]
# First let's create a tablespace "pg1" on our /pg1 directory: (we need the END; statement so that tablespace creation is executed without error)

# %%
%%sql
-- create a new tablespace
END;
CREATE TABLESPACE pg1 LOCATION '/pg1';

# %% [markdown]
# And let's create a database on pg1 tablespace.
#
# Note that, since we already have the "imdb" database, we will create imdb1 for practice purposes.

# %%
%%sql
-- create a new database imdb1 on pg1 tablespace
END;
CREATE DATABASE imdb1
TABLESPACE = pg1;

# %% [markdown]
# Now connect to the new imdb1 database

# %%
%sql postgres://postgres@localhost/imdb1

# %% [markdown]
# ### Create and copy data into title_ratings table

# %% [markdown]
# Make sure we are connected to the newly created imdb1 database:

# %%
%sql postgres://postgres@localhost/imdb1

# %% [markdown]
# And create a new table title_ratings with defined fields and types
#
# Note that, we cannot use "." dot inside table and field names

# %%
%%sql
-- create a new table
CREATE TABLE title_ratings
(
  tconst text,
  averageRating numeric,
  numVotes integer
);

# %% [markdown]
# In order to copy files from the local filesystem into the postgresql server, it is best to use the psql command:

# %%
 psql -U postgres -d imdb1 -c "\copy title_ratings from $imdbdir/tsv3/title.ratings2.tsv"

# %% [markdown]
# Note that this runs the COPY command of SQL under the hood, however it does not fall onto file read privilege problems:
#
#
#
# >Assuming the psql command-line tool, you may use \copy instead of copy.
# >
# >\copy opens the file and feeds the contents to the server, whereas copy tells the server the open the file itself and read it, which may be problematic permission-wise, or even impossible if client and server run on different machines with no file sharing in-between.
# >
# >Under the hood, \copy is implemented as COPY FROM stdin and accepts the same options than the server-side COPY.
# >
#
# (https://stackoverflow.com/questions/19463074/postgres-error-could-not-open-file-for-reading-permission-denied#19466558)
#
# Another advantage of using the "\copy" syntax through psql on Bash is that we can easily pass environment variables such as $imdbdir

# %% [markdown]
# Now we can check the table exists by using psql meta-command to describe the tables inside a database:

# %%
psql -U postgres -d imdb1 -c "\dt+"

# %% [markdown]
# And get the size of the database:

# %%
%%sql
SELECT pg_size_pretty(pg_database_size('imdb1'));

# %% [markdown]
# Create, insert and drop operations after some time may leave a junk space inside the database. In this case, it is better to run the "vacuum" command:

# %%
%%sql
VACUUM FULL;

# %% [markdown]
# Now let's view the data:

# %%
%%sql
SELECT *
FROM title_ratings
LIMIT 5;

# %% [markdown]
# To delete the data inside a table we can either use "DELETE or TRUNCATE statements:

# %%
%%sql
DELETE FROM title_ratings;

# %% [markdown]
# Now check whether data is deleted:

# %%
%%sql
SELECT *
FROM title_ratings
LIMIT 5;

# %% [markdown]
# Now let's copy the data again, this time using the sql command COPY instead of psql built-in \copy:

# %%
%%sql
COPY title_ratings from '/home/jovyan/data/imdb/tsv3/title.ratings2.tsv'

# %%
%%sql
SELECT *
FROM title_ratings
LIMIT 5;

# %% [markdown]
# And delete data with TRUNCATE:

# %%
%%sql
TRUNCATE title_ratings;

# %%
%%sql
SELECT *
FROM title_ratings
LIMIT 5;

# %% [markdown]
# Check the size and vacuum:

# %%
%%sql
SELECT pg_size_pretty(pg_database_size('imdb1'));

# %%
%%sql
VACUUM FULL;

# %%
%%sql
SELECT pg_size_pretty(pg_database_size('imdb1'));

# %% [markdown]
# ### Primary keys

# %% [markdown]
# Now copy the data again using "\copy" meta-command of psql:

# %%
psql -U postgres -d imdb1 -c "\copy title_ratings from $imdbdir/tsv3/title.ratings2.tsv"

# %% [markdown]
# Let's report the total row count using countrows alias. Note that "count()" is an example of the aggregate functions to summarize data:
#
# Note that we define an alias "countrows" for the aggregate calculation we do after SELECT:

# %%
%%sql
SELECT count(*) as countrows
FROM title_ratings;

# %% [markdown]
# More info on aggregate functions at:
#
# https://www.postgresql.org/docs/current/static/functions-aggregate.html
#
# And alias topic is covered in:
#
# https://www.postgresql.org/docs/10/static/queries-table-expressions.html

# %% [markdown]
# Now, with a mistake, run the COPY query again! (either with psql's \copy or sql COPY)

# %%
%%sql
COPY title_ratings
FROM '/home/jovyan/data/imdb/tsv3/title.ratings2.tsv';

# %%
%%sql
SELECT count(*) as countrows
FROM title_ratings;

# %% [markdown]
# We have twice the number of rows now, because postgresql did not complain to duplicate the same data!
#
# We should define a primary key on the table and put a constraint on the uniqueness of that key
#  But no problem we can ALTER anything in the table after it is first created:

# %%
%%sql
ALTER TABLE title_ratings
ADD CONSTRAINT title_ratings_pk 
PRIMARY KEY (tconst);

# %% [markdown]
# It threw an integrity error: The data are duplicated and a primary key cannot have duplicate values!

# %% [markdown]
# Now let's drop the table alltogether (not delete the contents):

# %%
%%sql
DROP TABLE title_ratings;

# %% [markdown]
# Create the table again with the constraint:

# %%
%%sql
-- create a new table
CREATE TABLE title_ratings
(
  tconst text,
  averageRating numeric,
  numVotes integer,

CONSTRAINT title_ratings_pk
   PRIMARY KEY (tconst)
    
);

# %% [markdown]
# And import data:

# %%
%%sql
COPY title_ratings
FROM '/home/jovyan/data/imdb/tsv3/title.ratings2.tsv';

# %% [markdown]
# Get the row count:

# %%
%%sql
SELECT count(*) as countrows
FROM title_ratings;

# %% [markdown]
# And try to import the data again:

# %%
%%sql
COPY title_ratings
FROM '/home/jovyan/data/imdb/tsv3/title.ratings2.tsv';

# %% [markdown]
# It did not allow us because uniqueness constraint prevented us to create duplicate values of primary key fields

# %% [markdown]
# **EXERCISE 1:**
#
# Import the title.episode2.tsv into title_episode table in imdb1 database
#
# - First create the table and the fields with appropriate types, including the primary key
# - Then import the data
#
# Remember the structure of title.episode:
#
# - title.episode.tsv: 72 MB, 2,986,926 lines, 4 fields. Contains the tv episode information. Fields include:
# - tconst (string) - alphanumeric identifier of episode
# - parentTconst (string) - alphanumeric identifier of the parent TV Series
# - seasonNumber (integer) – season number the episode belongs to
# - episodeNumber (integer) – episode number of the tconst in the TV series.
#
# Note that, -- defines a commented line not to be executed
#
# And always finish your statements with a semicolon ";"

# %%
%%sql

-- type your statement here

# %%
psql -U postgres -d imdb1 <<EOF

-- or you may write your statement here
EOF

# %% [markdown]
# **SOLUTION 1:**

# %%
pass1=
encrypt="U2FsdGVkX19fL3ZRoTCbtF1KZ9onuO616t3++mXfoHW6bGrMWcoRBDrUBk/YM5VJ j88eS5+6fA4oYm0V96zw4/9qzgBW4Gu594+lLxW/TQ9xqzODOyRi4j4pIAXIffP0 yrMiwyscX8n20jTEINctgC8/eM6rxM+C+zforrKwZWt0lcxbOarz8OqWZDn8MhRk k0piDCSrj3m4S/tLMl9VJNPwCxLe+RAEmjbCHbMlV+kEcsi6WyfuZhj34UE8H1V2 9/4w8ILi5Z9uJkgaAmEl1RUUHzGKCiNxelC3l2H3xfcjk+QGRZAzodtHEBOLVKoz e+trtOLlLeaaSt4dlz/c02uYecdHchRwqhdonZQVoaYfDZMnJoLMvDY8O//9KAfJ"
solution=$(echo $encrypt | openssl enc -md sha256 -aes-128-cbc -a -d -salt -pass pass:$pass1 2> /dev/null)
echo "$solution"; echo
for l in "$solution"; do eval "${l}"; done

# %% [markdown]
# ## Meta-commands

# %% [markdown]
# psql and pgcli clients offer some meta-commands that start with "\" and that offer shortcuts to some common operations
#
# You can get help on that using "\?" - a meta-command itself

# %%
psql -U postgres -c "\?"
# Out:
# General
#   \copyright             show PostgreSQL usage and distribution terms
#   \crosstabview [COLUMNS] execute query and display results in crosstab
#   \errverbose            show most recent error message at maximum verbosity
#   \g [FILE] or ;         execute query (and send results to file or |pipe)
#   \gdesc                 describe result of query, without executing it
#   \gexec                 execute query, then execute each value in its result
#   \gset [PREFIX]         execute query and store results in psql variables
#   \gx [FILE]             as \g, but forces expanded output mode
#   \q                     quit psql
#   \watch [SEC]           execute query every SEC seconds
#
# Help
#   \? [commands]          show help on backslash commands
#   \? options             show help on psql command-line options
#   \? variables           show help on special variables
#   \h [NAME]              help on syntax of SQL commands, * for all commands
#
# Query Buffer
#   \e [FILE] [LINE]       edit the query buffer (or file) with external editor
#   \ef [FUNCNAME [LINE]]  edit function definition with external editor
#   \ev [VIEWNAME [LINE]]  edit view definition with external editor
#   \p                     show the contents of the query buffer
#   \r                     reset (clear) the query buffer
#   \s [FILE]              display history or save it to file
#   \w FILE                write query buffer to file
#
# Input/Output
#   \copy ...              perform SQL COPY with data stream to the client host
#   \echo [STRING]         write string to standard output
#   \i FILE                execute commands from file
#   \ir FILE               as \i, but relative to location of current script
#   \o [FILE]              send all query results to file or |pipe
#   \qecho [STRING]        write string to query output stream (see \o)
#
# Conditional
#   \if EXPR               begin conditional block
#   \elif EXPR             alternative within current conditional block
#   \else                  final alternative within current conditional block
#   \endif                 end conditional block
#
# Informational
#   (options: S = show system objects, + = additional detail)
#   \d[S+]                 list tables, views, and sequences
#   \d[S+]  NAME           describe table, view, sequence, or index
#   \da[S]  [PATTERN]      list aggregates
#   \dA[+]  [PATTERN]      list access methods
#   \db[+]  [PATTERN]      list tablespaces
#   \dc[S+] [PATTERN]      list conversions
#   \dC[+]  [PATTERN]      list casts
#   \dd[S]  [PATTERN]      show object descriptions not displayed elsewhere
#   \dD[S+] [PATTERN]      list domains
#   \ddp    [PATTERN]      list default privileges
#   \dE[S+] [PATTERN]      list foreign tables
#   \det[+] [PATTERN]      list foreign tables
#   \des[+] [PATTERN]      list foreign servers
#   \deu[+] [PATTERN]      list user mappings
#   \dew[+] [PATTERN]      list foreign-data wrappers
#   \df[anptw][S+] [PATRN] list [only agg/normal/procedures/trigger/window] functions
#   \dF[+]  [PATTERN]      list text search configurations
#   \dFd[+] [PATTERN]      list text search dictionaries
#   \dFp[+] [PATTERN]      list text search parsers
#   \dFt[+] [PATTERN]      list text search templates
#   \dg[S+] [PATTERN]      list roles
#   \di[S+] [PATTERN]      list indexes
#   \dl                    list large objects, same as \lo_list
#   \dL[S+] [PATTERN]      list procedural languages
#   \dm[S+] [PATTERN]      list materialized views
#   \dn[S+] [PATTERN]      list schemas
#   \do[S]  [PATTERN]      list operators
#   \dO[S+] [PATTERN]      list collations
#   \dp     [PATTERN]      list table, view, and sequence access privileges
#   \drds [PATRN1 [PATRN2]] list per-database role settings
#   \dRp[+] [PATTERN]      list replication publications
#   \dRs[+] [PATTERN]      list replication subscriptions
#   \ds[S+] [PATTERN]      list sequences
#   \dt[S+] [PATTERN]      list tables
#   \dT[S+] [PATTERN]      list data types
#   \du[S+] [PATTERN]      list roles
#   \dv[S+] [PATTERN]      list views
#   \dx[+]  [PATTERN]      list extensions
#   \dy     [PATTERN]      list event triggers
#   \l[+]   [PATTERN]      list databases
#   \sf[+]  FUNCNAME       show a function's definition
#   \sv[+]  VIEWNAME       show a view's definition
#   \z      [PATTERN]      same as \dp
#
# Formatting
#   \a                     toggle between unaligned and aligned output mode
#   \C [STRING]            set table title, or unset if none
#   \f [STRING]            show or set field separator for unaligned query output
#   \H                     toggle HTML output mode (currently off)
#   \pset [NAME [VALUE]]   set table output option
#                          (NAME := {border|columns|expanded|fieldsep|fieldsep_zero|
#                          footer|format|linestyle|null|numericlocale|pager|
#                          pager_min_lines|recordsep|recordsep_zero|tableattr|title|
#                          tuples_only|unicode_border_linestyle|
#                          unicode_column_linestyle|unicode_header_linestyle})
#   \t [on|off]            show only rows (currently off)
#   \T [STRING]            set HTML <table> tag attributes, or unset if none
#   \x [on|off|auto]       toggle expanded output (currently off)
#
# Connection
#   \c[onnect] {[DBNAME|- USER|- HOST|- PORT|-] | conninfo}
#                          connect to new database (currently "postgres")
#   \conninfo              display information about current connection
#   \encoding [ENCODING]   show or set client encoding
#   \password [USERNAME]   securely change the password for a user
#
# Operating System
#   \cd [DIR]              change the current working directory
#   \setenv NAME [VALUE]   set or unset environment variable
#   \timing [on|off]       toggle timing of commands (currently off)
#   \! [COMMAND]           execute command in shell or start interactive shell
#
# Variables
#   \prompt [TEXT] NAME    prompt user to set internal variable
#   \set [NAME [VALUE]]    set internal variable, or list all if no parameters
#   \unset NAME            unset (delete) internal variable
#
# Large Objects
#   \lo_export LOBOID FILE
#   \lo_import FILE [COMMENT]
#   \lo_list
#   \lo_unlink LOBOID      large object operations

# %% [markdown]
# "\l" lists databases:

# %%
psql -U postgres -c "\l"
# Out:
#                               List of databases
#    Name    |  Owner   | Encoding | Collate |  Ctype  |   Access privileges
# -----------+----------+----------+---------+---------+-----------------------
#  imdb2     | postgres | UTF8     | C.UTF-8 | C.UTF-8 |
#  postgres  | postgres | UTF8     | C.UTF-8 | C.UTF-8 |
#  template0 | postgres | UTF8     | C.UTF-8 | C.UTF-8 | =c/postgres          +
#            |          |          |         |         | postgres=CTc/postgres
#  template1 | postgres | UTF8     | C.UTF-8 | C.UTF-8 | =c/postgres          +
#            |          |          |         |         | postgres=CTc/postgres
#  world     | postgres | UTF8     | C.UTF-8 | C.UTF-8 |
# (5 rows)

# %% [markdown]
# "\c" connects to database:

# %%
psql -U postgres -c "\c imdb2"
# Out:
# You are now connected to database "imdb2" as user "postgres".

# %% [markdown]
# "\dt" lists tables in a database:
# "\dt+" gives more detail

# %%
psql -U postgres -d imdb2 -c "\dt+"
# Out:
#                              List of relations
#  Schema |         Name          | Type  |  Owner   |  Size   | Description
# --------+-----------------------+-------+----------+---------+-------------
#  public | crew_molten           | table | postgres | 464 MB  |
#  public | genres_molten         | table | postgres | 334 MB  |
#  public | name_basics           | table | postgres | 676 MB  |
#  public | title_basics          | table | postgres | 516 MB  |
#  public | title_crew            | table | postgres | 260 MB  |
#  public | title_episode         | table | postgres | 167 MB  |
#  public | title_principals_melt | table | postgres | 1262 MB |
#  public | title_ratings         | table | postgres | 38 MB   |
# (8 rows)

# %% [markdown]
# "\d" lists fields in a table
#
# "\d+" gives more detail:

# %%
psql -U postgres -d imdb2 -c "\d+ title_basics"
# Out:
#                                     Table "public.title_basics"
#      Column     |  Type   | Collation | Nullable | Default | Storage  | Stats target | Description
# ----------------+---------+-----------+----------+---------+----------+--------------+-------------
#  tconst         | text    |           | not null |         | extended |              |
#  titletype      | text    |           |          |         | extended |              |
#  primarytitle   | text    |           |          |         | extended |              |
#  originaltitle  | text    |           |          |         | extended |              |
#  isadult        | boolean |           |          |         | plain    |              |
#  startyear      | integer |           |          |         | plain    |              |
#  endyear        | integer |           |          |         | plain    |              |
#  runtimeminutes | integer |           |          |         | plain    |              |
#  genres         | text    |           |          |         | extended |              |
# Indexes:
#     "tconst_pk" PRIMARY KEY, btree (tconst)
# Referenced by:
#     TABLE "crew_molten" CONSTRAINT "tconst_fk_01" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "genres_molten" CONSTRAINT "tconst_fk_03" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "title_crew" CONSTRAINT "tconst_fk_04" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "title_episode" CONSTRAINT "tconst_fk_05" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "title_episode" CONSTRAINT "tconst_fk_06" FOREIGN KEY (parenttconst) REFERENCES title_basics(tconst)
#     TABLE "title_principals_melt" CONSTRAINT "tconst_fk_07" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "title_ratings" CONSTRAINT "tconst_fk_09" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)

# %% [markdown]
# To get detailed information on all tables and primary keys in the public schema (like a named directory of databases, tables and keys)

# %%
psql -U postgres -d imdb2 -c "\d+ public.*"
# Out:
#                                  Table "public.crew_molten"
#    Column   | Type | Collation | Nullable | Default | Storage  | Stats target | Description
# ------------+------+-----------+----------+---------+----------+--------------+-------------
#  tconst     | text |           | not null |         | extended |              |
#  profession | text |           | not null |         | extended |              |
#  nconst     | text |           | not null |         | extended |              |
# Indexes:
#     "tconst_pk_08" PRIMARY KEY, btree (tconst, profession, nconst)
# Foreign-key constraints:
#     "tconst_fk_01" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     "tconst_fk_02" FOREIGN KEY (nconst) REFERENCES name_basics(nconst)
#
#                               Table "public.genres_molten"
#  Column | Type | Collation | Nullable | Default | Storage  | Stats target | Description
# --------+------+-----------+----------+---------+----------+--------------+-------------
#  tconst | text |           | not null |         | extended |              |
#  genres | text |           | not null |         | extended |              |
# Indexes:
#     "tconst_pk_07" PRIMARY KEY, btree (tconst, genres)
# Foreign-key constraints:
#     "tconst_fk_03" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#
#                                       Table "public.name_basics"
#       Column       |  Type   | Collation | Nullable | Default | Storage  | Stats target | Description
# -------------------+---------+-----------+----------+---------+----------+--------------+-------------
#  nconst            | text    |           | not null |         | extended |              |
#  primaryname       | text    |           |          |         | extended |              |
#  birthyear         | integer |           |          |         | plain    |              |
#  deathyear         | integer |           |          |         | plain    |              |
#  primaryprofession | text    |           |          |         | extended |              |
#  knownfortitles    | text    |           |          |         | extended |              |
# Indexes:
#     "tconst_pk_05" PRIMARY KEY, btree (nconst)
# Referenced by:
#     TABLE "crew_molten" CONSTRAINT "tconst_fk_02" FOREIGN KEY (nconst) REFERENCES name_basics(nconst)
#     TABLE "title_principals_melt" CONSTRAINT "tconst_fk_08" FOREIGN KEY (principalcast) REFERENCES name_basics(nconst)
#
#                   Index "public.tconst_pk"
#  Column | Type | Key? | Definition | Storage  | Stats target
# --------+------+------+------------+----------+--------------
#  tconst | text | yes  | tconst     | extended |
# primary key, btree, for table "public.title_basics"
#
#                  Index "public.tconst_pk_02"
#  Column | Type | Key? | Definition | Storage  | Stats target
# --------+------+------+------------+----------+--------------
#  tconst | text | yes  | tconst     | extended |
# primary key, btree, for table "public.title_crew"
#
#                       Index "public.tconst_pk_03"
#     Column     | Type | Key? |  Definition   | Storage  | Stats target
# ---------------+------+------+---------------+----------+--------------
#  tconst        | text | yes  | tconst        | extended |
#  principalcast | text | yes  | principalcast | extended |
# primary key, btree, for table "public.title_principals_melt"
#
#                  Index "public.tconst_pk_04"
#  Column | Type | Key? | Definition | Storage  | Stats target
# --------+------+------+------------+----------+--------------
#  tconst | text | yes  | tconst     | extended |
# primary key, btree, for table "public.title_ratings"
#
#                  Index "public.tconst_pk_05"
#  Column | Type | Key? | Definition | Storage  | Stats target
# --------+------+------+------------+----------+--------------
#  nconst | text | yes  | nconst     | extended |
# primary key, btree, for table "public.name_basics"
#
#                  Index "public.tconst_pk_06"
#  Column | Type | Key? | Definition | Storage  | Stats target
# --------+------+------+------------+----------+--------------
#  tconst | text | yes  | tconst     | extended |
# primary key, btree, for table "public.title_episode"
#
#                  Index "public.tconst_pk_07"
#  Column | Type | Key? | Definition | Storage  | Stats target
# --------+------+------+------------+----------+--------------
#  tconst | text | yes  | tconst     | extended |
#  genres | text | yes  | genres     | extended |
# primary key, btree, for table "public.genres_molten"
#
#                    Index "public.tconst_pk_08"
#    Column   | Type | Key? | Definition | Storage  | Stats target
# ------------+------+------+------------+----------+--------------
#  tconst     | text | yes  | tconst     | extended |
#  profession | text | yes  | profession | extended |
#  nconst     | text | yes  | nconst     | extended |
# primary key, btree, for table "public.crew_molten"
#
#                                     Table "public.title_basics"
#      Column     |  Type   | Collation | Nullable | Default | Storage  | Stats target | Description
# ----------------+---------+-----------+----------+---------+----------+--------------+-------------
#  tconst         | text    |           | not null |         | extended |              |
#  titletype      | text    |           |          |         | extended |              |
#  primarytitle   | text    |           |          |         | extended |              |
#  originaltitle  | text    |           |          |         | extended |              |
#  isadult        | boolean |           |          |         | plain    |              |
#  startyear      | integer |           |          |         | plain    |              |
#  endyear        | integer |           |          |         | plain    |              |
#  runtimeminutes | integer |           |          |         | plain    |              |
#  genres         | text    |           |          |         | extended |              |
# Indexes:
#     "tconst_pk" PRIMARY KEY, btree (tconst)
# Referenced by:
#     TABLE "crew_molten" CONSTRAINT "tconst_fk_01" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "genres_molten" CONSTRAINT "tconst_fk_03" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "title_crew" CONSTRAINT "tconst_fk_04" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "title_episode" CONSTRAINT "tconst_fk_05" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "title_episode" CONSTRAINT "tconst_fk_06" FOREIGN KEY (parenttconst) REFERENCES title_basics(tconst)
#     TABLE "title_principals_melt" CONSTRAINT "tconst_fk_07" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     TABLE "title_ratings" CONSTRAINT "tconst_fk_09" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#
#                                  Table "public.title_crew"
#   Column   | Type | Collation | Nullable | Default | Storage  | Stats target | Description
# -----------+------+-----------+----------+---------+----------+--------------+-------------
#  tconst    | text |           | not null |         | extended |              |
#  directors | text |           |          |         | extended |              |
#  writers   | text |           |          |         | extended |              |
# Indexes:
#     "tconst_pk_02" PRIMARY KEY, btree (tconst)
# Foreign-key constraints:
#     "tconst_fk_04" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#
#                                    Table "public.title_episode"
#     Column     |  Type   | Collation | Nullable | Default | Storage  | Stats target | Description
# ---------------+---------+-----------+----------+---------+----------+--------------+-------------
#  tconst        | text    |           | not null |         | extended |              |
#  parenttconst  | text    |           |          |         | extended |              |
#  seasonnumber  | integer |           |          |         | plain    |              |
#  episodenumber | integer |           |          |         | plain    |              |
# Indexes:
#     "tconst_pk_06" PRIMARY KEY, btree (tconst)
# Foreign-key constraints:
#     "tconst_fk_05" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     "tconst_fk_06" FOREIGN KEY (parenttconst) REFERENCES title_basics(tconst)
#
#                              Table "public.title_principals_melt"
#     Column     | Type | Collation | Nullable | Default | Storage  | Stats target | Description
# ---------------+------+-----------+----------+---------+----------+--------------+-------------
#  tconst        | text |           | not null |         | extended |              |
#  principalcast | text |           | not null |         | extended |              |
# Indexes:
#     "tconst_pk_03" PRIMARY KEY, btree (tconst, principalcast)
# Foreign-key constraints:
#     "tconst_fk_07" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)
#     "tconst_fk_08" FOREIGN KEY (principalcast) REFERENCES name_basics(nconst)
#
#                                    Table "public.title_ratings"
#     Column     |  Type   | Collation | Nullable | Default | Storage  | Stats target | Description
# ---------------+---------+-----------+----------+---------+----------+--------------+-------------
#  tconst        | text    |           | not null |         | extended |              |
#  averagerating | numeric |           |          |         | main     |              |
#  numvotes      | integer |           |          |         | plain    |              |
# Indexes:
#     "tconst_pk_04" PRIMARY KEY, btree (tconst)
# Foreign-key constraints:
#     "tconst_fk_09" FOREIGN KEY (tconst) REFERENCES title_basics(tconst)

# %% [markdown]
# And let's visualize the database with an entity-relationship diagram (You can also find this diagram as [png](imdb_erd.png) file):

# %% [markdown]
# ![aa](imdb_erd.png)

# %% [markdown]
# See that here we have some additional tables to enhance our queries, and they do not exist in the original imdb database:

# %% [markdown]
# crew_molten, splits multiple directors or writers from commas, and has an additional field for director/writer profession:

# %%
%load_ext sql
%sql postgres://postgres@localhost/imdb2
# Out:
# 'Connected: postgres@imdb2'

# %%
%%sql
SELECT * FROM crew_molten
LIMIT 5;
# Out:
#  * postgres://postgres@localhost/imdb2
# 5 rows affected.
# [('tt0000001', 'director', 'nm0005690'),
#  ('tt0000002', 'director', 'nm0721526'),
#  ('tt0000003', 'director', 'nm0721526'),
#  ('tt0000004', 'director', 'nm0721526'),
#  ('tt0000005', 'director', 'nm0005690')]

# %% [markdown]
# genres_molten, has tconst and genres field split from commas:

# %%
%%sql
SELECT * FROM genres_molten
LIMIT 5;
# Out:
#  * postgres://postgres@localhost/imdb2
# 5 rows affected.
# [('tt0000001', 'Documentary'),
#  ('tt0000001', 'Short'),
#  ('tt0000002', 'Animation'),
#  ('tt0000002', 'Short'),
#  ('tt0000003', 'Animation')]

# %% [markdown]
# title_principals_melt has the tconst and principalcast field split from the commas:

# %%
%%sql
SELECT * FROM title_principals_melt
LIMIT 5;
# Out:
#  * postgres://postgres@localhost/imdb2
# 5 rows affected.
# [('tt0000001', 'nm1588970'),
#  ('tt0000001', 'nm0374658'),
#  ('tt0000001', 'nm0005690'),
#  ('tt0000002', 'nm1335271'),
#  ('tt0000002', 'nm0721526')]

# %% [markdown]
# ## Basic Query and Filter operations: SELECT with WHERE

# %% [markdown]
# Now we will use the full database "imdb" in our PostgreSQL server:

# %% [markdown]
# list fields and data info

# %%
%load_ext sql

# %%
%sql postgres://postgres@localhost/imdb2
# Out:
# 'Connected: postgres@imdb2'

# %% [markdown]
# In our basic "SELECT" queries we will start with a few clauses:
#
# * SELECT: columns and aggretations on columns
# * FROM: tables to query
# * WHERE: conditions to filter rows
# * ORDER: the column(s) to order the results
# * LIMIT: maximum number of rows to return

# %% [markdown]
# * Select all titles which include "Godfather" and "Part" words in it, with any number of character before, between or after
# * Report tconst id, original title, start year, run time in minutes and genres
# * Order them by increasing runtimeminutes:

# %%
%%sql

SELECT tconst, originaltitle, startyear, runtimeminutes, genres
  FROM title_basics
  WHERE originaltitle ~ 'Godfather.*Part'
  ORDER BY runtimeminutes;
# Out:
#  * postgres://postgres@localhost/imdb2
# 10 rows affected.
# [('tt5942862', 'The Godfather vs. The Godfather Part II', 2008, 2, 'Documentary,Short'),
#  ('tt5280194', 'Storyboards: The Godfather Part III', 2001, 4, 'Short'),
#  ('tt6620222', 'The Godfather: Part II', 2017, 12, 'Documentary'),
#  ('tt0539894', 'The Godfather: Part 3', 1987, 30, 'Comedy,Drama'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama'),
#  ('tt4667260', 'The Godfather Part IV', 2015, None, 'Drama'),
#  ('tt6083390', 'The Godfather Part III/Kindergarten Cop/The Bonfire of the Vanities/The Russia House', 1990, None, 'Talk-Show'),
#  ('tt2255473', 'The Rise and Fall of a Godfather: Part 1', 1992, None, 'News'),
#  ('tt2255475', 'The Rise and Fall of a Godfather: Part 2', 1992, None, 'News')]

# %% [markdown]
# In fact we are not concerned with documentaries, shorts and comedy movies
#
# So we should include only dramas and exclude comedies and let's sort by runtimeminutes in descending order

# %%
%%sql

SELECT tconst, originaltitle, startyear, runtimeminutes, genres
  FROM title_basics
  WHERE originaltitle ~ 'Godfather.*Part'
	AND genres ~ 'drama'
  ORDER BY runtimeminutes;
# Out:
#  * postgres://postgres@localhost/imdb2
# 0 rows affected.
# []

# %% [markdown]
# The query did not return any rows?
#
# Why?
#
# Because regex pattern search is case sensitive unless otherwise states and "drama" does not match "Drama"
#
# In order to make the search case insensitive we add (?i) at the beginning of the pattern or we can use ~* operator which makes the pattern case insensitive:

# %%
%%sql

SELECT tconst, originaltitle, startyear, runtimeminutes, genres
  FROM title_basics
  WHERE originaltitle ~ 'Godfather.*Part'
	AND genres ~ '(?i)drama'
  ORDER BY runtimeminutes DESC;
# Out:
#  * postgres://postgres@localhost/imdb2
# 4 rows affected.
# [('tt4667260', 'The Godfather Part IV', 2015, None, 'Drama'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama'),
#  ('tt0539894', 'The Godfather: Part 3', 1987, 30, 'Comedy,Drama')]

# %% [markdown]
# **EXERCISE 2:**
#
# - Select originaltitle, startyear, runtimeminutes and genres columns
# - From title_basics table
# - Where originaltitle includes "Star Wars"
# - And start year greater than 1977
# - Sort by descending runtimeminutes
#
# Note: You can try below cells or pgcli from the terminal to test your commands

# %%
%%sql

select originaltitle, startyear, runtimeminutes, genres
from title_basics
where originaltitle ~ '(?i)Star Wars' and startyear>=1977
order by runtimeminutes desc
# Out:
#  * postgres://postgres@localhost/imdb2
# 1149 rows affected.
# [('Star Wars: Legacy - War', 2011, None, 'Comedy'),
#  ('Super Star Wars: Return of the Jedi', 1994, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars Arcade', 2007, None, 'Comedy,History'),
#  ('Top 10 Star Wars Games', 2015, None, 'Comedy,Talk-Show'),
#  ("Star Wars: Saving Marion's Booty Part 1: Imperial Incarceration", 2015, None, 'Animation,Short'),
#  ('Star Wars: Rise of the Grey Jedi', 2018, None, 'Fantasy,Sci-Fi,Short'),
#  ('May the Fourth Be With You - 5 datos trivia de Star Wars - CineBananas', 2015, None, 'News,Reality-TV'),
#  ('We\'re Getting a Visit from Two of the Movies\' Most Iconic Characters: R2-D2 and C-3PO from "Star Wars: The Force Awakens"!', 2016, None, 'Talk-Show'),
#  ('Star Wars: Masters of Teras Kasi', 2013, None, 'Comedy,History'),
#  ('Star Wars: Early Learning Activity Center', 2000, None, 'Family'),
#  ('Star Wars in the Classroom', 2016, None, 'Documentary'),
#  ("Where's Rey? Star Wars Monopoly Set Missing Lead Character Set Piece", 2016, None, 'Talk-Show'),
#  ('Star Wars Angry Birds en Jouets', 2013, None, 'Comedy'),
#  ('Le Pire Jeu Star Wars?', 2015, None, 'Comedy'),
#  ('Extraction: Star Wars', 2016, None, 'Action,Short'),
#  ('Star Wars Celebration', 2015, None, 'Documentary'),
#  ('First Look at Luke Skywalker in Star Wars: The Force Awakens', 2015, None, 'Talk-Show'),
#  ('Skywalker Story Focus of Star Wars Episode VII', 2015, None, 'Talk-Show'),
#  ('New Cast Member for Star Wars Episode VIII Revealed?', 2015, None, 'Talk-Show'),
#  ('Star Wars: The Force Awakens Trailer Review and Breakdown Special', 2015, None, 'Talk-Show'),
#  ('Star Wars Kylo Ren Lightsaber Cake - The Force Awakens', 2015, None, 'Talk-Show'),
#  ('Star Wars Episode VII: The Force Awakens', 2015, None, 'Comedy'),
#  ('Rogue One: A Star Wars Story', 2016, None, 'Comedy'),
#  ('Kinect Star Wars en 5 secondes', 2012, None, 'Comedy'),
#  ('Star Wars - I Love Your Buns Leia (Clif Bar)', 2016, None, 'Comedy,Musical,Short'),
#  ('Star Wars: Prelude to a Requiem', 2009, None, 'Sci-Fi,Short'),
#  ('Star Wars VII - Le Réveil de la Force', 2015, None, 'Comedy'),
#  ('BigHead Star Wars Force Awakens: Kylo Ren vs. Finn', 2016, None, 'Comedy,Short'),
#  ('BigHead Star Wars Force Awakens: Han and Kylo Ren', 2016, None, 'Comedy,Short'),
#  ('Age of the Empire: A Star Wars Story', 2017, None, 'Sci-Fi,Short'),
#  ('Star Wars Celebration Predictions: Rogue One, Episode 8, Rebels', 2016, None, 'Talk-Show'),
#  ('Star Wars Celebration 2016 Recap and Breakdown', 2016, None, 'Talk-Show'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Action,Adventure,Comedy'),
#  ('How to Fix Star Wars (With Videogames)', 2013, None, 'Documentary,Short'),
#  ("Talking Star Wars Comics and Rogue One's U-Wing", 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Talking Star Wars Rebels and the Joy of Cosplay', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars Live Action TV Series in Talks for ABC', 2016, None, 'Talk-Show'),
#  ('Star Wars: Masters of Teras Kasi (PS1)', 2001, None, 'Animation'),
#  ('Trevor Noah Interview, Star Wars at Shanghai Disneyland, and More', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars: Go Rogue', 2016, None, 'Animation,Comedy,Sci-Fi'),
#  ('Pablo Hidalgo Interview and Star Wars Battlefront: Death Star DLC Preview', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars: The Force Awakens', 2016, None, 'Comedy'),
#  ('Star Wars Elevator Prank', 2013, None, 'Comedy,Short'),
#  ("Let's Play: Star Wars Battle Pod Arcade Game - Hoth, Death Star, Endor Levels", 2015, None, 'Documentary'),
#  ('Star Wars: The Old Republic - Knights of the Eternal Throne', 2016, None, 'Action'),
#  ('New Rogue One Posters, Star Wars Rebels Season 3 and More!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Rebellion: A Star Wars Story', 2016, None, 'Sci-Fi,Short'),
#  ('What If Star Wars...', 2016, None, None),
#  ('On the Star Wars Set!', 2015, None, 'Talk-Show'),
#  ('Star Wars épisode IV de George Lucas par M. Bobine', 2009, None, 'Short'),
#  ('Best Star Wars Character Ever??', 2016, None, 'Comedy'),
#  ('Star Wars: Sith Lords - Legends', 2017, None, 'Sci-Fi,Short'),
#  ('Star Wars: Episode VIII Teaser Reactions', 2016, None, 'Talk-Show'),
#  ('Do the Star Wars Prequels Really Suck?', 2016, None, 'Talk-Show'),
#  ('Star Wars Rogue One: Deciphering the Dark Future of Star Wars - Frame by Frame', 2016, None, 'Animation,Comedy,Talk-Show'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Documentary'),
#  ('Our Favorite Star Wars Art and Designs!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('What If Star Wars...', 2016, None, None),
#  ('Non! Rogue One (Star Wars)', 2016, None, 'Comedy'),
#  ('Star Wars (NES)', 2016, None, None),
#  ('The Star Wars Holiday Special (1978)', 2016, None, 'Comedy'),
#  ('The Star Wars Holiday Special (1978)', 2017, None, 'Comedy'),
#  ("Hannah Hart, Rogue One: Recon Event, and Fans' Favorite Star Wars Books", 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('The Star Wars Show Holiday Special!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Return to Star Wars', 2016, None, 'Comedy'),
#  ('Star Wars: The Phantom Menace (PC)', 2012, None, 'Comedy,Talk-Show'),
#  ('STAR WARS SEX SCENE', 2016, None, 'Game-Show'),
#  ('Way to the Rebellion - A Star Wars Fan Film', 2016, None, None),
#  ('Light of Hope Update, Star Wars, Warcraft', 2015, None, 'Comedy,Short'),
#  ('Why Are There No Handrails in Star Wars? How Rogue One Recreated Classic Sets', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Which Rogue One Alien Wears an iPhone and a Major Marvel Star Wars Comics Crossover Revealed', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Rogue One: A Star Wars Story', 2016, None, 'Talk-Show'),
#  ('Rogue One Comes Home, a Big Celebration Panel Announced, and the Star Wars Collecting Rule', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('TubeHeads Special: Star Wars, Das Erwachen der Macht', 2016, None, 'Comedy'),
#  ("Star Trek's Tim Russ Explains Star Wars Day", 2015, None, 'Comedy'),
#  ('STAR WARS CLUE', 2016, None, 'Reality-TV'),
#  ('Hot Wheels All Access: Star Wars Character Cars', 2016, None, 'Documentary'),
#  ('Star Wars Yoda Stories - PC Game Review', 2014, None, 'Reality-TV'),
#  ('Mais um papo sobre Star Wars', 2014, None, 'News,Short'),
#  ('Star Wars: Hunting of the Fallen', 2016, None, 'Sci-Fi,Short'),
#  ('The Grey Jedi: A Star Wars Story', 2017, None, 'Sci-Fi,Short'),
#  ('Rogue One: A Star Wars Story Trailer 3 Thoughts', 2016, None, 'Comedy'),
#  ('Rogue One: A Star Wars Story', 2016, None, 'Comedy'),
#  ('Star Wars: Return of the Jedi', 2017, None, 'Comedy'),
#  ('Star Wars Sithposting (Meme War/The Hacking Incidents)', 2017, None, 'Talk-Show'),
#  ('Inside Forces of Destiny and Star Wars Animation, Plus Lightsaber Training and Droid Unboxing!', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Why do we love Star Wars?', 2015, None, 'Comedy'),
#  ('How Bad Is the Star Wars Holiday Special???', 2016, None, 'Comedy'),
#  ('Star Wars: The Force Awakens', 2016, None, 'Comedy'),
#  ('Crítica a Star Wars Rebels', 2014, None, 'Animation,Comedy,News'),
#  ('Star Wars: Rogue One Review', 2017, None, 'Comedy'),
#  ('The Star Wars #5', 2017, None, 'Comedy,Sci-Fi'),
#  ('Wish Upon a Star Wars', 2016, None, 'Sci-Fi,Short'),
#  ('Star Wars - Five Way', 2017, None, 'Game-Show'),
#  ('ROGUE ONE: A STAR WARS STORY', 2016, None, 'News'),
#  ('Star Wars Boba Fett: Lost on Earth', 2016, None, 'Sci-Fi,Short'),
#  ('Wrestling Star Wars', 1981, None, 'Sport'),
#  ('Star Wars Rebels Final Season', 2017, None, 'Talk-Show'),
#  ('Star Wars: Imperials', 2017, None, None),
#  ('Star Wars: Stealing the Plans', 2016, None, 'Sci-Fi,Short'),
#  ('Star Wars: Shrouded Destiny', 2018, None, 'Sci-Fi,Short'),
#  ("Star Wars Day Highlights at Lucasfilm & runDisney's Star Wars Half Marathon!", 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Rogue One: A Star Wars Story', 2016, None, 'Comedy,Talk-Show'),
#  ('Star Wars Day 2017', 2017, None, 'Comedy'),
#  ('Star Wars Teaser: Vader vs Obi Juan', 2013, None, 'Comedy'),
#  ('Star Wars Popped', 2018, None, 'Comedy'),
#  ('Final de temporada: Civil War, Star Wars, Black Widow y Captain Marvel', 2016, None, 'Comedy'),
#  ('Star Wars', 2017, None, 'Drama,Romance'),
#  ('Fall of Creation a Star Wars Fan Film', 2017, None, None),
#  ('Super Star Wars: Return of the Jedi', 1994, None, 'Action,Sci-Fi'),
#  ('Monopoly Star Wars', 1997, None, 'Family,Sci-Fi'),
#  ('Star Wars: Episode I - The Gungan Frontier', 1999, None, 'Family,Sci-Fi'),
#  ('Star Wars: Episode I - The Phantom Menace', 1999, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Episode I - Jedi Power Battles', 2000, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars: X-Wing Alliance', 1999, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars', 1983, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Episode I - Battle for Naboo', 2001, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Galactic Battlegrounds', 2001, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars Galaxies: An Empire Divided', 2003, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Obi-Wan', 2002, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars', 1987, None, 'Action,Adventure,Fantasy'),
#  ('Super Star Wars', 1992, None, 'Action,Adventure,Sci-Fi'),
#  ('Super Star Wars: The Empire Strikes Back', 1993, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Return of the Jedi - Death Star Battle', 1983, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Rogue Squadron II - Rogue Leader', 2001, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Millennium Falcon CD-ROM Playset', 1998, None, None),
#  ('Star Wars: Bounty Hunter', 2002, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Rebel Assault', 1993, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Jedi Knight - Jedi Academy', 2003, None, 'Action,Drama,Fantasy'),
#  ("Saving 'Star Wars'", 2004, None, 'Comedy'),
#  ('Science of Star Wars', 2005, None, 'Documentary'),
#  ('Star Wars Galaxies: Jump to Lightspeed', 2004, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars Galaxies: Rage of the Wookiees', 2005, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Episode III - Revenge of the Sith', 2005, None, 'Action,Adventure,Drama'),
#  ("World Premiere 'Star Wars III: Revenge of the Sith'", 2005, None, None),
#  ('Star Wars Creatures', 2005, None, 'Documentary'),
#  ('Star Trek Vs Star Wars', 2005, None, 'News,Talk-Show'),
#  ('Ken Lay/Submission/The Last Star Wars', 2005, None, 'Documentary,News'),
#  ('Bring Back... Star Wars', 2008, None, 'Documentary'),
#  ('Star Wars Battlefront: Renegade Squadron', 2007, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: The Force Unleashed', 2008, None, 'News,Talk-Show'),
#  ('Star Wars: The Clone Wars', 2008, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars Celebration', 2005, None, 'Documentary,News'),
#  ('Majokko Star Wars!?', 1992, None, 'Animation,Family,Fantasy'),
#  ('Star Wars: Episode III - Revenge of the Sith', 2005, None, None),
#  ("I've Never Seen Star Wars", 2009, None, 'Comedy'),
#  ('Operation Olivia: The Star Wars Fan Film Challenge Episode One', 2009, None, 'Comedy,Short'),
#  ('The Rocker/Henry Poole is Here/Star Wars: The Clone Wars/Tropic Thunder/Fly Me to the Moon', 2008, None, 'Talk-Show'),
#  ('Star Wars: The New Droid Army', 2002, None, 'Action,Sci-Fi'),
#  ('Star Wars: Knights of the Old Republic', 2002, None, None),
#  ('Star Wars: The Original', 2002, None, None),
#  ('Lego Star Wars III: The Clone Wars', 2011, None, 'Sci-Fi'),
#  ('The Star Wars Holiday Special', 2009, None, 'Comedy'),
#  ('Selling Star Wars', 1985, None, 'Documentary,News'),
#  ('My Favorite Star Wars Character', 2011, None, 'Comedy'),
#  ('Star Wars: Episode III.VIII: Rise of the Troopers', 2007, None, 'Sci-Fi,Short'),
#  ('Star Wars vs Star Trek', 2006, None, 'Game-Show'),
#  ('Star Wars Holiday Special', 2010, None, 'Comedy,Sci-Fi'),
#  ('Star Wars Original Trilogy', 2011, None, 'Talk-Show'),
#  ('Lego Star Wars: Bible Stories', 2009, None, 'Adventure,Comedy,History'),
#  ('Star Wars: The Old Republic Fan Film', 2012, None, 'Action,Short'),
#  ('How Star Wars Episode IV Should Have Ended', 2005, None, 'Animation,Comedy'),
#  ('Star Wars Episode I: The Phantom Menace', 1999, None, 'Talk-Show'),
#  ('Kinect Star Wars: Duel', 2012, None, 'Sci-Fi'),
#  ("Drunk Star Wars II 'The Dylan Strikes Back'", 2012, None, 'Comedy,Documentary,News'),
#  ('Illegal Alien: Star Wars', 2012, None, 'Comedy,Short'),
#  ('The Cabin in the Woods and Kinect Star Wars', 2012, None, 'News'),
#  ('Kinect Star Wars', 2012, None, 'Action,Sci-Fi'),
#  ('Star Wars Celebration VI Special', 2012, None, 'Talk-Show'),
#  ('Star Wars', 2012, None, 'Game-Show,Reality-TV'),
#  ('Star Wars - Legacy', 2010, None, 'Comedy'),
#  ('Star Wars Kinect', 2012, None, 'Comedy'),
#  ('Disneyfied Star Wars Auditions', 2012, None, 'Comedy'),
#  ('Star Wars Chess', 1993, None, 'Sci-Fi'),
#  ('Star Wars: Hunt for the Holocron', 2013, None, 'Short'),
#  ('Kinect Star Wars: Girly Vader', 2012, None, 'Sci-Fi'),
#  ('TVTV Does Star Wars Holiday Special', 2009, None, 'Animation,Comedy,Horror'),
#  ('Super Star Wars: A New Jedi - Part 1', 2013, None, 'Comedy,Short,Talk-Show'),
#  ('Super Star Wars: The Sith Strikes Hope - Part 2', 2013, None, 'Comedy,Short,Talk-Show'),
#  ('Super Star Wars: The Phantom of the Clones - Part 3', 2013, None, 'Comedy,Short,Talk-Show'),
#  ('Super Star Wars: Return of the Revenge - Part 4', 2013, None, 'Comedy,Short,Talk-Show'),
#  ('Super Star Wars: Attack of the Back - Part 5', 2013, None, 'Comedy,Short,Talk-Show'),
#  ('Star Wars', 2005, None, 'Animation,Comedy'),
#  ('Angry Birds Star Wars', 2012, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars Episode 7: Directors List', 2012, None, 'Talk-Show'),
#  ('Star Wars Episode 7: Casting', 2012, None, 'Talk-Show'),
#  ("Star Wars & Angry Birds: McDonald's Happy Halloween Happy Meal", 2013, None, 'Short'),
#  ("K-1 Star Wars '96", 1996, None, 'Sport'),
#  ("Next-Gen Star Wars Goes Open World & Xbox One's Actual Cost", 2013, None, 'News'),
#  ('Angry Birds Star Wars II', 2013, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: The Complete Saga', 2011, None, None),
#  ('Star Wars Semantics', 2013, None, 'Comedy'),
#  ('Star Wars: The Force Unleashed Review', 2011, None, 'Game-Show'),
#  ('Star Wars: The Old Republic Review', 2012, None, 'Game-Show'),
#  ('SDi #39 - Aaron Groben (Star Wars Comics, Actor/Host)', 2014, None, 'Comedy'),
#  ('Star Wars Fashion', 2014, None, 'Talk-Show'),
#  ('Star Wars Noob', 2012, None, 'Comedy'),
#  ('A Star Wars Story: Untitled Han Solo Film', 2018, None, 'Action,Sci-Fi'),
#  ("Star Woes: The Pain of 'Star Wars' Fandom", 2013, None, 'Comedy'),
#  ('Council of Geeks Shorts: Returning Star Wars Characters', 2014, None, 'Comedy'),
#  ('Leaked Star Wars Auditions', 2014, None, 'Comedy,Music,Sci-Fi'),
#  ('Star Wars Rebels Spelling Bee: Billy Unger', 2014, None, None),
#  ('Star Wars Rebels Spelling Bee: Karan Brar', 2014, None, None),
#  ('Star Wars Rebels Spelling Bee: Bradley Steven Perry', 2014, None, None),
#  ('Star Wars Rebels Spelling Bee: Tyrel Jackson Williams', 2014, None, None),
#  ('Star Wars Rebels Spelling Bee: Kelli Berglund', 2014, None, None),
#  ('Fashionably Nerdy at Star Wars Weekends in Orlando', 2014, None, 'Talk-Show'),
#  ('Star Wars: The Scarlet Lance', 2014, None, 'Sci-Fi,Short'),
#  ('Star Wars: Blackout', 2014, None, 'Short'),
#  ('Star Wars Gets Gareth Edwards, Ant-Man Loses Edgar Wright', 2014, None, 'Talk-Show'),
#  ('Star Wars the Force Awakens Teaser Trailer Review', 2014, None, 'Comedy'),
#  ('Star Wars: The Old Republic - Shadow of Revan', 2014, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars Episode III: Seduction Spot', 2005, None, 'Sci-Fi,Short'),
#  ('Star Wars: Shadows of the Empire (N64) Part 1', 2015, None, 'Comedy,Talk-Show'),
#  ('Super Star Wars Return of the Jedi: Making History - Part 1: Grumpcade', 2015, None, None),
#  ('Super Star Wars Return of the Jedi - Part 2: Babu Fett!', 2015, None, None),
#  ('Star Wars Spinoffs - Good Idea or Bad Idea?', 2015, None, 'Talk-Show'),
#  ('Star Wars Special', 2014, None, 'Sport,Talk-Show'),
#  ('The Betrayal: Epic Star Wars Fan Film', 2015, None, 'Action'),
#  ('Unleash the Force with the Force Trainer II: Hologram Experience & Star Wars Science from Uncle Milton', 2015, None, 'News'),
#  ('Star Wars Holiday Special', 2012, None, 'Talk-Show'),
#  ('Star Wars: Armada', 2015, None, 'News'),
#  ('Comic-Con 2015: Sexy Cosplay, Thanos, Star Wars, & More!!', 2015, None, 'Comedy'),
#  ('Defecit Levy & Star Wars VII', 2014, None, 'Comedy,News'),
#  ("Disney World's Star Wars Land Dream Rides!?", 2015, None, 'Talk-Show'),
#  ('StarCade Episode 4: Nintendo Star Wars', 2015, None, 'Comedy'),
#  ('Star Wars Rebels: Recon Missions', 2015, None, 'Action,Fantasy,Sci-Fi'),
#  ('Star Wars: Battle of Rocket City', 2016, None, 'Action,Adventure,Sci-Fi'),
#  ('The Screen Writing Mind Tricks of STAR WARS - Frame by Frame', 2015, None, 'Animation,Comedy,Talk-Show'),
#  ('Star Wars: The Force Awakens & William Wall', 2015, None, 'Sci-Fi'),
#  ('Star Wars: Please Kathleen Kennedy', 2014, None, 'Short'),
#  ('Star Wars - Episode IV', 2010, None, 'Comedy'),
#  ('Star Wars Over Starbucks', 2015, None, 'Comedy,Short'),
#  ('StarCade Episode 7: Star Wars Plug and Play', 2015, None, 'Comedy'),
#  ('Star Wars Episode V Egg Parody', 2011, None, 'Comedy,Short'),
#  ('Star Wars', 2015, None, 'Comedy'),
#  ('Star Wars Love Advice (BTS)', 2015, None, None),
#  ('Silent Hill & Star Wars', 2014, None, None),
#  ('Elders React to Star Wars: The Force Awakens', 2015, None, 'Comedy,Reality-TV'),
#  ('Star Wars: The Idiotic Clone Trooper', 2014, None, 'Action,Animation,Comedy'),
#  ('Top 10 Worst Star Wars Special Edition Changes', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars Death Star Cake', 2015, None, 'Reality-TV'),
#  ('Star Wars: The Force Awakens Review! (No Spoilers)', 2015, None, 'Comedy'),
#  ('Star Wars: Masters of Teras Kasi - Game Grumps VS', 2015, None, 'Comedy,Short,Talk-Show'),
#  ('Star Wars: The Force Awakens Thoughts (Spoilers!)', 2015, None, 'Reality-TV'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Talk-Show'),
#  ('Star Wars: Battlefront', 2015, None, None),
#  ('Star Wars Games', 2015, None, 'Documentary,Short'),
#  ('Lego Star Wars "Phantom Menace" (XBox 360)', 2015, None, 'Comedy,Talk-Show'),
#  ('Review of Star Wars the Force Awakens', 2015, None, 'Comedy'),
#  ('Star Wars Holiday Special!', 2015, None, 'Comedy'),
#  ('Star Wars Chess', 2015, None, 'Comedy,Sci-Fi'),
#  ('Nintendo Star Wars', 2015, None, 'Comedy,Sci-Fi'),
#  ('Star Wars: Battlefront', 2016, None, 'Comedy'),
#  ('Star Wars Special: Episode 1', 2016, None, 'News'),
#  ('Top 6 Craziest STAR WARS Facts', 2015, None, 'Comedy'),
#  ("Luke SHOULDN'T Destroy the Death Star (Star Wars)", 2016, None, 'Animation,Comedy,Talk-Show'),
#  ('AbsurdTV Ep 111 Star Wars Celebration Fat Mama', 2015, None, 'Comedy'),
#  ('The Force Awakens Cast Plays "Star Wars or Florida?"', 2015, None, 'Talk-Show'),
#  ('Star Wars Jetpacks in Real Life', 2016, None, 'Comedy'),
#  ('Star Wars Holiday Special', 2015, None, 'Comedy'),
#  ('Lego Star Wars: The Force Awakens', 2016, None, 'Adventure,Sci-Fi'),
#  ('Star Wars Superfan', 2015, None, 'Comedy'),
#  ('Star Wars Episode IV: A New Hope', 2015, None, 'Talk-Show'),
#  ('Star Wars: Rise of the First Order', 2017, None, None),
#  ('Star Wars: Shadows of the Empire', 1996, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Jedi Knight - Dark Forces II', 1997, None, 'Action,Fantasy,Sci-Fi'),
#  ('Star Wars: Black Sands', 2014, None, 'Action,Fantasy,Short'),
#  ('Star Wars Holiday Special', 2014, None, 'Comedy'),
#  ('Dennis Muren, Star Wars Table Top Games, and Star Wars Fan Film Awards News', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars vs Star Trek, Super Powers & Getting Turned On!', 2013, None, 'Talk-Show'),
#  ("If Star Wars Wasn't Serious", 2014, None, 'Action,Comedy'),
#  ('New Star Wars Video Games, Han Solo #1 Preview, and Nick Swardson', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Elders Play Star Wars Battlefront', 2015, None, 'Comedy,Short'),
#  ('How to Date a Star Wars Hater', 2015, None, 'Comedy,Short'),
#  ('Star Wars the Force Awakens Trailer - Piano Cover', 2016, None, 'Music'),
#  ('Star Wars: Rivals (a Fan Film)', 2016, None, 'Sci-Fi,Short'),
#  ('New Rogue One Characters Revealed, LEGO Star Wars: The Freemaker Adventures', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('The Star Wars Show LIVE! Celebration Europe 2016', 2016, None, 'Reality-TV,Sci-Fi'),
#  ('Star Wars: The Force of Abrams', 2016, None, 'Comedy'),
#  ('Star Wars Rebels Season 3 Clip, Gareth Edwards Interview, and More!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Action Movie Kid, Missing Yoda Statue, Star Wars at SDCC, and More', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('The Force Returns: Star Wars Trilogy Special Edition', 1997, None, 'Documentary'),
#  ('The Star Wars After Show', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars: The Force Awakens', 2016, None, 'Comedy,Family'),
#  ('Soirée Pizza - Star Wars Kinect!', 2015, None, 'Game-Show'),
#  ('The Best Star Wars Toys & Our Favorite Droids', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Harry Potter VS Star Wars', 2014, None, 'Action'),
#  ('Rancho Obi-Wan Visit, Playing Star Wars: Racer Arcade, and More', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('ESSENTIAL STAR WARS ITEMS', 2016, None, 'Game-Show'),
#  ('The Music of Star Wars Rebels, Marvel Star Wars and More!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Sacrificio: A Star Wars Fan Film', 2017, None, 'Sci-Fi,Short'),
#  ('Star Wars: Battlefront - Outer Rim', 2016, None, 'Action,Fantasy,Sci-Fi'),
#  ('Lego Star Wars: The Force Awakens', 2016, None, None),
#  ('Star Wars Rebels Season 3 Clip and Marvel Editor Jordan D. White Interview', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ("Shadow Conspiracy/Waiting for Guffman/Star Wars: Special Edition/Gridlock'd/Prisoner of the Mountains/Walkabout", 1997, None, 'Talk-Show'),
#  ("Star Wars épisode V d'Irvin Kershner par M. Bobine", 2009, None, 'Short'),
#  ('Star Wars épisode VI de Richard Marquand par M. Bobine', 2009, None, 'Short'),
#  ("Ken Loach's Star Wars", 2015, None, 'Comedy,Short'),
#  ("ROGUE ONE's Turn to the Darkside (Star Wars: Rogue One)", 2016, None, 'Animation,Comedy,Talk-Show'),
#  ('Why Death Is Meaningless in Star Wars', 2016, None, 'Comedy,Sci-Fi'),
#  ('A Prelude to War: Star Wars Fan Film', 2017, None, 'Sci-Fi,Short'),
#  ('Star Wars - Across the Stars Piano Cover', 2016, None, 'Music'),
#  ('Star Wars: Episode V - The Empire Strikes Back', 2016, None, 'Comedy'),
#  ('The History of Late Night - Star Wars', 2016, None, 'Comedy'),
#  ('Going to a Star Wars Store', 2015, None, 'Comedy'),
#  ('The Star Wars Holiday Special', 2016, None, 'Comedy'),
#  ('Scout: A Star Wars Story', 2017, None, 'Sci-Fi,Short'),
#  ('Star Wars', 2016, None, 'Comedy'),
#  ('The Legendary Colin Cantwell (Original Star Wars Ship Designer) Interview', 2017, None, 'Talk-Show'),
#  ('Black Ops 3, Star Wars Battlefront, and Rocket League', 2015, None, 'Comedy'),
#  ('Stormtrooper Reacts to Star Wars VIII Announcement', 2016, None, 'Comedy,Sci-Fi,Short'),
#  ('Stormtroopers Singing Star Wars Theme', 2016, None, 'Comedy,Sci-Fi,Short'),
#  ('Star Wars Rogue One: Stormtrooper Reacts', 2017, None, 'Comedy,Sci-Fi,Short'),
#  ('Disney Star Wars Sing-Along Songs', 2012, None, 'Comedy,Short'),
#  ('Star Wars HACKS & BOOTLEGS!', 2016, None, 'Comedy,Talk-Show'),
#  ('Star Wars: Return of the Sith', 2010, None, 'Short'),
#  ('Star Wars Commander', 2015, None, 'Comedy'),
#  ('The Director of Rogue One, a Star Wars Museum, and MORE!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars vs. Star Trek', 2017, None, 'Comedy'),
#  ('Star Wars VII: The Force Awakens', 2015, None, 'Talk-Show'),
#  ('Star Wars: Grey Squadron', 2017, None, 'Action,Adventure,Sci-Fi'),
#  ('The Cast of Rogue One Visits the Star Wars Show and More!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars Battlefront. Stars of Russian Cast.', 2015, None, None),
#  ('Star Wars Rogue One Music Video: Resolute Determination', 2016, None, 'Music,Short'),
#  ('Star Wars Video Games Coming to Celebration and Rebuilding the Rebel Base for Rogue One', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('STAR WARS CAKE OFF', 2016, None, 'Reality-TV'),
#  ('Star Wars: Galactic Battlegrounds - Clone Campaigns', 2002, None, None),
#  ('Star Wars: The Mission', 2017, None, 'Sci-Fi,Short'),
#  ('Star Wars: Operation Sigma', 2017, None, 'Action,Short'),
#  ('Re-creating Tarkin & Leia in Rogue One, Plus Star Wars Trivia... On a Rollercoaster!', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars: The Force Awakens ASMR REY Hair & Makeup Tutorial', 2016, None, 'Reality-TV,Short'),
#  ('Star Wars Challenge', 2016, None, 'Family'),
#  ('Trail of Fear/Star Wars/License to Kill/Getting Even', 1993, None, None),
#  ('Rogue One: A Star Wars Story', 2017, None, 'Comedy'),
#  ('Star Wars DroidWorks: Robot Abomination Simulator', 2017, None, 'Reality-TV'),
#  ('NYFA Plays Star Wars Battlefront', 2017, None, None),
#  ('Star Wars', 2015, None, 'Talk-Show'),
#  ('El hombre que nunca ha visto Star Wars', 2015, None, 'Comedy'),
#  ('Star Wars (1977)', 2015, None, None),
#  ("The Making of Darth Vader's Castle and Chris Conley on His Love of Star Wars", 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ("10 Questions About the 'Star Wars: The Last Jedi' Teaser Trailer", 2017, None, 'News'),
#  ("Too 10 Star Wars Facts You Probably Didn't Know!", 2017, None, 'Comedy,Talk-Show'),
#  ("Christian Frates' Star Wars Impressions", 2017, None, 'Sci-Fi,Short'),
#  ('Star Wars: The Force Awakens Parody "Kylo Ren\'s Obsession"', 2016, None, 'Comedy'),
#  ('Rogue One - A Star Wars Story', 2016, None, 'Documentary'),
#  ('Star Wars', 2017, None, 'Comedy'),
#  ('Star Wars histoire et mythologie', 2015, None, 'History'),
#  ('Star Wars Celebration', 2015, None, None),
#  ('Star Wars: Episode II - Attack of the Clones', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars: Episode III - Revenge of the Sith', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars', 2015, None, 'Comedy,Talk-Show'),
#  ('Odyssey: A Star Wars Story', 2018, None, 'Action,Short'),
#  ('Mark Reilly & Wendy Lee - Star Wars on Weed', 2017, None, 'Comedy,Talk-Show'),
#  ('Star Wars: Scramble on Uylara', 2018, None, 'Fantasy,Short'),
#  ('Is Technology Dangerous? (Star Wars + Heidegger)', 2015, None, 'Comedy'),
#  ('Star Wars: The Empire Strikes Back', 1985, None, 'Action,Sci-Fi'),
#  ('Star Wars: Force Commander', 2000, None, 'Sci-Fi'),
#  ('Star Wars: Demolition', 2000, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Jedi Arena', 1983, None, 'Action,Sci-Fi'),
#  ('Star Wars: The Empire Strikes Back', 1982, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Racer Revenge', 2002, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars: The Clone Wars', 2002, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Battlefront', 2004, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Republic Commando', 2005, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: Knights of the Old Republic II - The Sith Lords', 2004, None, 'Action,Adventure,Drama'),
#  ('Star Wars Galaxies: The Total Experience', 2005, None, 'Action,Adventure,Drama'),
#  ('Lego Star Wars: The Video Game', 2005, None, 'Action,Adventure,Comedy'),
#  ('Star Wars', 2000, None, 'Comedy'),
#  ('Star Wars 2 Premiere', 2002, None, 'Comedy,Documentary'),
#  ('Troldspejlet Special: Star Wars: Episode III - Sith fyrsternes hævn', 2005, None, None),
#  ('Star Wars/Andrew W.K./FTX/Tractor Pull', 2005, None, 'Comedy,Documentary,News'),
#  ('Lego Star Wars II: The Original Trilogy', 2006, None, 'Action,Adventure,Comedy'),
#  ('Troldspejlet Special: Star Wars: Episode I - Den usynlige fjende', 1999, None, None),
#  ('Star Wars: Galaxies - Trials of Obi-Wan', 2005, None, 'Action,Adventure'),
#  ('Star Wars: The Force Unleashed', 2008, None, 'Action,Adventure,Drama'),
#  ('Waiting for Star Wars', 1999, None, None),
#  ('Lego Star Wars: The Complete Saga', 2007, None, 'Action,Adventure,Comedy'),
#  ('Star Wars', 1980, None, 'Comedy'),
#  ('Star Wars at 30', 2007, None, None),
#  ('Star Wars Premiere, Apprentice Finale and More', 2005, None, 'Comedy'),
#  ('Star Wars: The Old Republic', 2011, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Episode III - Revenge of the Sith', 2005, None, 'Documentary'),
#  ('Star Wars: The Clone Wars - Republic Heroes', 2009, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars: The Force Unleashed - Ultimate Sith Edition', 2009, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars Cinematech', 2005, None, None),
#  ("The Secret of 'Star Wars'", 1983, None, 'Talk-Show'),
#  ('Star Wars - Episódio XX: A Descoberta do Jedi', 2010, None, 'Short'),
#  ('The Star Wars Fan', 2010, None, 'Sci-Fi,Short'),
#  ('Star Wars Arcade', 1996, None, 'Action'),
#  ('Star Wars: Rebellion', 1998, None, 'Sci-Fi'),
#  ('Star Wars Cakes', 2011, None, 'Game-Show,Reality-TV'),
#  ('Star Wars para Atari 2600', 2011, None, 'Comedy'),
#  ('Here Come the Star Wars Clone Wars', 2008, None, 'Talk-Show'),
#  ('Star Wars', 2011, None, 'Reality-TV'),
#  ('Star Wars', 2011, None, 'Comedy,War'),
#  ('Desert Island Star Wars', 2011, None, 'Comedy'),
#  ('Star Trek vs Star Wars', 2011, None, 'Comedy'),
#  ('The Star Wars Prequels', 2011, None, 'Comedy'),
#  ('Call of Duty XP, Star Wars and Justice League', 2011, None, 'News'),
#  ('Star Wars: Enlistees', 2007, None, 'Sci-Fi,Short'),
#  ('Anniversary, Star Wars, Makerfaire', 2007, None, 'Music,News'),
#  ('Star Wars Uncut + Footloose Remake = Creative Awesomeness', 2010, None, 'Music,News'),
#  ("Creative Team Behind 'Star Wars Episode I: The Phantom Menace'", 2011, None, 'Talk-Show'),
#  ('Drunk Star Wars', 2012, None, 'Comedy,Documentary,News'),
#  ('Whatever Happened to Star Wars?', 1993, None, 'Documentary'),
#  ('The Star Wars Prequel Trilogy', 2012, None, 'Talk-Show'),
#  ('Star Wars Starring Chris Tucker', 2011, None, 'Comedy,Short'),
#  ('Star Wars: Basics', 2012, None, None),
#  ('Star Wars: Classic Trilogy', 2012, None, None),
#  ('Leaked Disney Star Wars 7 Trailer', 2012, None, 'Comedy,Short'),
#  ('Star Wars: The Last Jedi', 2017, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Episode IX', 2019, None, 'Action,Adventure,Fantasy'),
#  ('George Lucas: Star Wars', 2012, None, 'Comedy,News'),
#  ('Disney/Star Wars Corporate Retreat', 2013, None, 'Comedy'),
#  ('Disney Star Wars', 2013, None, 'Comedy,Fantasy,Sci-Fi'),
#  ('The Science of Star Wars Exhibition', 2012, None, 'News'),
#  ('Star Wars Cookies', 2012, None, 'Reality-TV'),
#  ('Seth Green on Stand Up Trauma, Child Actors and Star Wars', 2012, None, 'Talk-Show'),
#  ("The Creative Team Behind 'Star Wars Episode I: The Phantom Menace' 2", 2013, None, 'Talk-Show'),
#  ('Star Wars Holiday Special Opening Revisited', 2012, None, 'Animation,Comedy,Horror'),
#  ('Serious Star Wars Fans: A Day with the 501st Legion', 2013, None, 'Short'),
#  ('Star Wars Lightsaber Popsicles', 2013, None, 'Reality-TV'),
#  ('Star WarsIII/Mysterious Skin/Unleashed', 2005, None, 'News'),
#  ('FanAddicts!: Star Wars & Scooby Doo', 2013, None, 'Reality-TV'),
#  ("Star Wars' Yoda Stew and Aunt Beru's Blue Milk", 2013, None, 'Talk-Show'),
#  ("Oh Gawd Star Wars and Star Trek, I'm Gonna Wear a Boba Fett Costume", 2013, None, 'Talk-Show'),
#  ('Star Wars, Flamingos, Typewriters, James Bond', 2002, None, 'Reality-TV'),
#  ('High Noon Auction, Tiffany, Toy Trains, G.I. Joe, Star Wars', 2001, None, None),
#  ('Star Wars Downunder', 2013, None, 'Sci-Fi,Short'),
#  ('Star Wars Day Special', 2013, None, 'Talk-Show'),
#  ('Star Wars', 2014, None, 'Comedy'),
#  ('Peter Mayhew from "Star Wars"', 2014, None, 'Talk-Show'),
#  ('Star Wars: Le sabre laser pourrait-il exister?', 2011, None, 'Documentary,Sci-Fi'),
#  ('Star Wars: Battlefront', 2015, None, 'Action,Fantasy,Sci-Fi'),
#  ('Star Wars Cantina Band Auditions', 2014, None, 'Comedy'),
#  ('Star Wars: The New Republic', 2014, None, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars VII: Return of the Empire', 2013, None, 'Action,Comedy,Short'),
#  ('Star Wars: Episode 2 - Attack of the Clones', 2014, None, 'Comedy'),
#  ('Star Wars', 2014, None, 'Reality-TV'),
#  ('Star Wars: The Empire Strikes Back', 2014, None, 'Reality-TV'),
#  ('Star Wars: Return of the Jedi', 2014, None, 'Reality-TV'),
#  ('Star Wars: The Phantom Menace', 2014, None, 'Reality-TV'),
#  ('Star Wars: Attack of the Clones', 2014, None, 'Reality-TV'),
#  ('Star Wars: Revenge of the Sith', 2014, None, 'Reality-TV'),
#  ('Star Wars', 2010, None, 'Sci-Fi'),
#  ('A Long Time Ago-The Story of Star Wars', 1999, None, 'Biography,Documentary,Music'),
#  ('Star Wars Kinect Is AWESOME!', 2012, None, 'Comedy,Game-Show'),
#  ('Anglophiles and Star Wars 7', 2012, None, 'Comedy'),
#  ('Star Wars Rebels, Jimi: All Is by My Side, Gracepoint, the Equalizer', 2014, None, 'Talk-Show'),
#  ('Star Wars VS Star Trek', 2014, None, 'Talk-Show'),
#  ('New Star Wars Lightsaber - Awesome or Useless?', 2014, None, 'Talk-Show'),
#  ('Star Wars Episode III: Becoming Obi-Wan', 2005, None, 'Sci-Fi,Short'),
#  ('Star Wars: Grand Moff Mix-Up', 2014, None, 'Comedy'),
#  ('Today in Nerd History: The Star Wars Holiday Special', 2014, None, 'Comedy'),
#  ('Why Star Wars Is Secretly Racist', 2014, None, 'Comedy'),
#  ('Disney Buys Star Wars and DFTVA!', 2012, None, 'Comedy,Documentary,Music'),
#  ('Star Wars: Shadows of the Empire (N64) Part 2', 2015, None, 'Comedy,Talk-Show'),
#  ('George Lucas and Anakin Skywalker React to New Star Wars Teaser', 2014, None, 'Comedy,Short'),
#  ('Star Wars: Shadows of the Empire (N64) Part 3', 2015, None, 'Comedy,Talk-Show'),
#  ('Should Star Wars Ditch George Lucas?', 2015, None, 'Talk-Show'),
#  ('YouTubers React to Star Wars: The Force Awakens', 2014, None, 'Comedy,Reality-TV'),
#  ('Super Star Wars Return of the Jedi - Part 3: Luke Peewalker', 2015, None, None),
#  ('Sea Star Wars', 2015, None, 'Talk-Show'),
#  ('Star Wars Day Special', 2015, None, 'News'),
#  ('Patton Oswalt Talks DC, Marvel, Star Wars & More!', 2015, None, 'Comedy'),
#  ('Star Wars - "Death Star Trench Run"', 2013, None, None),
#  ("Food Trucks, Star Wars and Brenda Lee's Pie", 2014, None, None),
#  ('Star Wars: Battle of Hoth', 2014, None, 'Comedy'),
#  ('Top 10 Star Wars Video Games (Redux)', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars Celebration Live Anaheim 2015', 2015, None, 'Reality-TV,Sci-Fi'),
#  ('Director Rob Cohen + Star Wars, Jurassic World, Batman v. Superman Trailers!', 2015, None, 'Talk-Show'),
#  ('Star Wars: A New Hope - Analyzed by Aliens - Earthling Cinema', 2015, None, 'Comedy'),
#  ('Star Wars: The Empire Strikes Back - Analyzed by Aliens - Earthling Cinema', 2015, None, 'Comedy'),
#  ('Star Wars Fanservice', 2015, None, 'Comedy,Short'),
#  ('Star Wars: Uprising', 2015, None, 'Fantasy,Sci-Fi'),
#  ('Which Is Nerdier: Star Wars or Star Trek?', 2015, None, 'Comedy'),
#  ('StarCade Episode 3: Star Wars Chess', 2015, None, 'Comedy'),
#  ("Untitled Visceral Games' Star Wars Project", 2018, None, 'Action,Adventure,Sci-Fi'),
#  ('Lego Star Wars: Droid Tales', 2015, None, 'Animation,Sci-Fi'),
#  ('Star Wars Legacy: Darth Krayt', 2014, None, 'Animation,Short'),
#  ('Ackbar! The Star Wars Talk Show', 2009, None, 'Comedy'),
#  ('Geekly News - STAR WARS, STAN LEE, JOSS WHEDON, DISNEY and MORE!!', 2014, None, 'News'),
#  ('Geekly News - STAR WARS, DEATH of WOLVERINE, JUSTICE LEAGUE', 2014, None, 'News'),
#  ('Star Wars On-Set Secrets Ft. JonTron - Did You Know Movies?', 2015, None, 'Animation,Comedy,Talk-Show'),
#  ('Star Wars: Precious Cargo', 2015, None, 'Action,Adventure,Fantasy'),
#  ('Derp Vader - Star Wars Parody', 2014, None, 'Family'),
#  ('The Vigilant Christian: "Star Wars Is Satanic!" - Holistic Christian - Killer Cop Goes Free!', 2014, None, 'Comedy,Game-Show,News'),
#  ('CraveCast - Hobbit Day, Star Wars and Sex Robots!', 2015, None, 'Talk-Show'),
#  ('Brazilian Star Wars', 2012, None, 'Comedy'),
#  ('Star Wars - Episode I, II, III & VI', 2011, None, 'Comedy'),
#  ('Star Wars: The Force Awakens - Final Trailer Reactions!', 2015, None, 'Comedy'),
#  ('Star Wars: The Old Republic - Knights of the Fallen Empire', 2015, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars the Force Awakens Trailer - Live Reaction', 2015, None, 'Comedy'),
#  ('Hellevator, Star Wars: The Force Awakens Trailer', 2015, None, 'Talk-Show'),
#  ('The Cast of Star Wars: The Force Awakens', 2015, None, 'Comedy,Music,Talk-Show'),
#  ('Star Wars IV Remaster Comparison', 2015, None, 'Talk-Show'),
#  ('Star Wars Battlefront Review', 2015, None, 'Talk-Show'),
#  ('The Star Wars Vault', 2015, None, None),
#  ('Star Wars: The Force Awakens', 2015, None, 'Talk-Show'),
#  ('Star Wars (Famicom)', 2015, None, 'Comedy,Talk-Show'),
#  ('Top 10 Star Wars Droids', 2015, None, 'Comedy,Talk-Show'),
#  ('Stupid Star Wars Rumors', 2015, None, 'Comedy'),
#  ('Star Wars Battlefront', 2015, None, None),
#  ('Star Wars Chess (Sega CD)', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars Episode III: Revenge of the Sith', 2015, None, 'Comedy'),
#  ('Star Wars NO Spoiler Review and Frank Oz Interview! The Force Awakens Is Here!', 2015, None, 'Talk-Show'),
#  ("Star Wars: Episode V - L'Empire contre-attaque", 2009, None, 'Comedy'),
#  ('Top 10 Star Wars: The Force Awakens Facts', 2015, None, 'Comedy,Talk-Show'),
#  ('Nimport Naouac Star Wars', 2015, None, 'Comedy'),
#  ('A New Direction on Drugs/The New Force Behind Star Wars/Lewis Hamilton', 2015, None, 'Documentary,News'),
#  ('Star Wars: Episode IV - A New Hope', 2015, None, 'Documentary'),
#  ('Star Wars: Episode V - The Empire Strikes Back', 2015, None, 'Documentary'),
#  ('Star Wars: Episode VI - Return of the Jedi', 2015, None, 'Documentary'),
#  ('Star Wars: Episode I - The Phantom Menace', 2015, None, 'Documentary'),
#  ('Star Wars: Episode II - Attack of the Clones', 2015, None, 'Documentary'),
#  ('Star Wars: Episode VII - The Force Awakens', 2015, None, 'Documentary'),
#  ('Star Wars: Special Editions', 2015, None, 'Documentary'),
#  ('Star Wars: Episode III - Revenge of the Sith', 2015, None, 'Documentary'),
#  ('Star Wars: The Force Awakens - SPOILER Review! (Ft. Max Landis)', 2015, None, 'Comedy'),
#  ("STAR WARS: Boba Fett's SECRET Origins - Did You Know Movies Ft. Furst", 2015, None, 'Animation,Comedy,Talk-Show'),
#  ('Is the Force Awakens the Best Star Wars Movie?', 2015, None, 'Talk-Show'),
#  ('Star Wars: The Force Awakens', 2015, None, 'News,Talk-Show'),
#  ('Star Wars Galactic Battle Grounds Part 1', 2015, None, 'Talk-Show'),
#  ('Star Wars: A New Gaming Era', 2015, None, 'Documentary'),
#  ('Star Wars, Buster Keaton, Dinosaur', 2016, None, 'Comedy'),
#  ('Star Wars: Gallactic Balltle Grounds Part 2', 2015, None, 'Talk-Show'),
#  ('Star Wars Real Commercials', 2015, None, 'Sci-Fi,Short'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Talk-Show'),
#  ('Star Wars Jedi Knight: Jedi Academy Part 3', 2015, None, 'Talk-Show'),
#  ('Lego Star Wars Part 1', 2016, None, 'Talk-Show'),
#  ('Jill and Jack do Star Wars Force Powers', 2015, None, 'Comedy'),
#  ('Zero Severed Hands: On Star Wars and Making Things', 2016, None, 'Comedy,Documentary,Music'),
#  ('Lego Star Wars Part 2', 2016, None, 'Talk-Show'),
#  ('Star Wars Special: Episode 2', 2016, None, 'News'),
#  ('Star Wars: Episode VII - Toys', 2015, None, 'Short'),
#  ('Star Wars', 2015, None, None),
#  ('Star Wars Lightsaber vs Halo Energy Sword', 2016, None, 'Animation,Comedy,Talk-Show'),
#  ('Star Wars', 2015, None, 'Comedy'),
#  ('R2-D2 Star Wars Chocolates', 2016, None, 'Reality-TV'),
#  ('Star Wars Battlefront Beta', 2015, None, 'Comedy,News,Short'),
#  ('Star Wars Battlefront Part 1', 2015, None, 'Comedy,News,Short'),
#  ('Star Wars Battlefront Part 2', 2015, None, 'Comedy,News,Short'),
#  ('Meg & Liz Reveal Their Secret About Star Wars', 2014, None, 'Comedy'),
#  ('Star Wars: Unity of the Force', 2016, None, 'Fantasy,Short'),
#  ('Star Wars, the Force Awakens', 2016, None, 'Talk-Show'),
#  ('Star Wars Acapella Cats', 2015, None, 'Comedy,Drama,Fantasy'),
#  ('Star Wars: Episode 1 Racer', 2006, None, None),
#  ('Star Wars: The Force Awakens... Spoiler Free - Comic City', 2015, None, 'News,Reality-TV'),
#  ("23 Things You Didn't Know Weren't in Star Wars", 2016, None, 'Comedy'),
#  ('Laff TV: Taylor Swift Star Wars Parody', 2015, None, 'Short'),
#  ('Best "Star Wars: Rogue One" Trailer Moment?', 2016, None, 'Talk-Show'),
#  ('J.J Abrams directs Episode IX? Desplat Scoring Star Wars: Rogue One', 2015, None, 'Talk-Show'),
#  ('New Star Wars: The Force Awakens Trailer and Star Wars Celebration', 2015, None, 'Talk-Show'),
#  ('Star Wars Celebration 2015', 2015, None, 'Talk-Show'),
#  ('Star Wars Press Begins!', 2015, None, 'Talk-Show'),
#  ('Benicio Del Toro the Villain in Star Wars Episode 8?', 2015, None, 'Talk-Show'),
#  ('Star Wars on Netflix??', 2015, None, 'Talk-Show'),
#  ('Star Wars in 1 Take in 6 Minutes', 2015, None, 'Comedy'),
#  ('Top 5 Star Wars Games', 2015, None, 'Talk-Show'),
#  ('Star Wars Revenge of the Morons', 2013, None, 'Comedy'),
#  ('Star Wars on Netflix', 2016, None, 'Sci-Fi,Short'),
#  ('Star Wars', 1999, None, 'Documentary,News'),
#  ('Star Wars Battlefront', 2016, None, 'Comedy,Short,Talk-Show'),
#  ('Star Wars: Journey of a Fan Film', 2015, None, 'Documentary,Short'),
#  ('CONtv Star Wars Party', 2015, None, 'Comedy'),
#  ('Star Wars', 1997, None, None),
#  ('Rogue One: A Star Wars Story', 2016, None, 'Comedy,News,Talk-Show'),
#  ('Reasons Why Star Wars the Force Awakens Sucks', 2016, None, 'Comedy'),
#  ('Chvrches, Games at Celebration, Star Wars in Japan', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Happy Star Wars Day!', 2017, None, 'Talk-Show'),
#  ('Sidewalk Star Wars, Skateboard Scrapes and a Waterslide Wipeout', 2016, None, 'Comedy'),
#  ('The Best Ever! Star Wars Game', 2015, None, None),
#  ('Star Wars: Elimination', 2018, None, 'Sci-Fi'),
#  ("Canncelled Star Wars Games You've Never Seen Before", 2016, None, 'Documentary,Short'),
#  ('Dave Filoni Interview, ANOVOS Star Wars Costumes, and More', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('The Star Wars Holiday Special', 2014, None, 'Comedy'),
#  ('Star Wars Battlefront at Gamescom and Rogue One Reactions', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars at Disneyland and New Stormtroopers', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Tour and Star Wars', 2016, None, 'Reality-TV'),
#  ('Star Wars: DroidWorks', 1998, None, 'Sci-Fi'),
#  ("The World's Biggest Star Wars Collection and More!", 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars: The Force Awakens', 2016, None, 'Comedy'),
#  ('Rogue One: A Star Wars Story (Final Trailer)', 2016, None, 'Comedy'),
#  ('Breaking Down the Star Wars Rebels Premiere', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars: Legends - Fan Made', 2016, None, 'Sci-Fi,Short'),
#  ('The Star Wars Holiday Special', 2015, None, 'Animation,Comedy,Documentary'),
#  ('Star Wars: Rough Cut (Fan Film)', 2016, None, 'Comedy,Short'),
#  ('Master Chief VS Jango Fett (Halo VS Star Wars)', 2016, None, 'Action,Animation,Comedy'),
#  ('Christian J Simpson: Star Wars Embarrassing Moment!', 2015, None, 'Talk-Show'),
#  ('STAR WARS 7, de J.J. Abrams - La critique par M. Bobine', 2016, None, 'Short'),
#  ('Geek Girl Problems: Star Wars!', 2015, None, 'Comedy,Talk-Show'),
#  ('Rogue One: A Star Wars Story', 2016, None, None),
#  ('Star Wars: Knights of the Old Republic', 2016, None, None),
#  ('The Real Reason Star Wars Droids Are Built to Feel Pain', 2016, None, 'Comedy,Sci-Fi'),
#  ('How Star Wars Should Have Ended (Special Edition)', 2016, None, None),
#  ("The Craziest Star Wars Interviews You've Never Seen! (Until Now!)", 2016, None, 'Comedy'),
#  ('Top 10 Things We Want to See in Future Star Wars Instalments', 2016, None, 'Comedy,Talk-Show'),
#  ('Star Wars: Rogue One Teaser Trailer Review and Reactions', 2016, None, 'Talk-Show'),
#  ('Star Wars: Rogue One - Movie Review', 2016, None, 'Comedy,Talk-Show'),
#  ('Star Wars Gingerbread Wookiee Cookies', 2016, None, 'Reality-TV'),
#  ('Top 10 Star Wars Creatures', 2016, None, 'Comedy,Talk-Show'),
#  ('Top 10 Star Wars Spin-Offs That NEED to Happen!', 2016, None, None),
#  ('Top 10 Star Wars Mistakes You May Have Missed', 2016, None, 'Comedy,Talk-Show'),
#  ('The New Force Behind Star Wars/Michael Caine/And the Nominees Are', 2016, None, 'Documentary,News'),
#  ('Star Wars Costumes, Fan Groups and More!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Tiya Sircar Miss India America And Star Wars Rebels', 2016, None, 'Talk-Show'),
#  ('Best Zombie Weapons - Minecraft, Star Wars, Halo, Super Mario', 2016, None, 'Comedy'),
#  ('Star Wars: Shadows of the Empire', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars: Lost Horizons', 2017, None, 'Sci-Fi'),
#  ('Star Wars: Shadows of the Empire', 2009, None, 'Comedy'),
#  ('Coleccionismo: Star Wars Black Series - Comic City', 2017, None, 'News,Reality-TV'),
#  ("Star Wars' Alan Dean Foster", 2015, None, 'Talk-Show'),
#  ('Timothy Zahn Star Wars', 2016, None, 'Talk-Show'),
#  ("Star Wars Fans Try CoverGirl's Makeup Line", 2015, None, None),
#  ('Talking the Future of Star Wars on the Set of Rogue One', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars: Le vrai visage de Darth Vader', 2016, None, 'Comedy'),
#  ('Star Wars Grabenkampf: Obi Wan vs. Navi', 2015, None, 'Comedy'),
#  ('Star Wars Awakens', 2016, None, None),
#  ('Star Wars Rebels Coming to Celebration Orlando and the Best Star Wars Video Games with Xavier Woods', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars Awakens', 2016, None, 'Family'),
#  ('Star Wars Awakens', 2016, None, 'Family'),
#  ('Star Wars: The Force Awakens ASMR Rey Wounded Soldier Roleplay FANFICTION (Theory)', 2016, None, 'Reality-TV,Short'),
#  ("Star Wars FanFilm the Padawan I 'The Beginning'", 2012, None, 'Sci-Fi'),
#  ('Star Wars Fireworks', 2016, None, 'Family'),
#  ('Star Wars: The Force and the Fury', 2017, None, 'Action,Short'),
#  ('DI Club Penguin - Star Wars Rebels Takeover', 2015, None, None),
#  ('Star Wars 3D, Making Of e CARNANERD', 2012, None, 'News'),
#  ('Star Wars Episode III - Revenge of the Sith', 2017, None, 'Comedy'),
#  ('Star Wars: Destroyer', 2017, None, 'Sci-Fi,Short'),
#  ('Level App: Lego Star Wars - The Force Awakens', 2016, None, 'Comedy,News'),
#  ('Star Wars X-Wing vs. TIE Fighter - PC Game Review', 2015, None, 'Reality-TV'),
#  ('The Star Wars Show LIVE! Celebration Orlando 2017', 2017, None, 'Reality-TV,Sci-Fi'),
#  ('Star Wars: Big Red Bow', 2014, None, 'Short'),
#  ('Is Star Wars Attacking White People?', 2015, None, 'Comedy,News,Talk-Show'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Comedy,News'),
#  ('STAR WARS: Trailer Reaction', 2015, None, 'News,Short'),
#  ('Adults React to Star Wars: The Last Jedi Official Trailer (Ft. FBE Staff)', 2017, None, 'Documentary'),
#  ('Star Wars: A New Hope as told by Tsum Tsum', 2016, None, 'Family'),
#  ('Level BackUp S07E03: Resident Evil VII, Kingdom Hearts Og Star Wars', 2017, None, 'Comedy,News'),
#  ('The Star Wars Holiday Special', 2015, None, 'Comedy'),
#  ('Top 5 Myths About Star Wars', 2017, None, 'Comedy,Talk-Show'),
#  ('Bureau des plaintes: Star Wars', 2017, None, None),
#  ('Star Wars: The Force Awakens, Batman v Superman y ¡Olivia Munn!', 2015, None, 'Comedy'),
#  ('Volver al Futuro, Star Wars: The Force Awakens y Fallout 4', 2015, None, 'Comedy'),
#  ('Star Wars Plans for Carrie Fisher Appearances - Is It the Best Way?', 2017, None, 'Comedy'),
#  ('Star Wars Episode VIII: The Last Jedi - Trailer Reaction', 2017, None, 'Comedy'),
#  ('Star Wars Issues', 2015, None, 'Comedy,Short'),
#  ("Adam Driver on 50-Pound Weight Loss, 'Girls' Finale and the Next 'Star Wars'", 2017, None, 'Talk-Show'),
#  ('Dissidents: A Star Wars Story', 2017, None, 'Action,Sci-Fi,Short'),
#  ('Top 10 Reasons Why the Star Wars Prequels Suck', 2017, None, 'Comedy,Talk-Show'),
#  ('Hopeless: A Star Wars Story', 2017, None, None),
#  ("'Star Wars' Supercut: Parodies of the Trench Run", 2017, None, 'News'),
#  ('The Last Jedi Director Rian Johnson, the Best of Celebration, & the Star Wars Show CANNON!', 2017, None, 'Sci-Fi,Short,Talk-Show'),
#  ('George Lucas - The Story of the Star Wars Prequels', 2016, None, 'Documentary'),
#  ('Star Wars: Turning Point', 2017, None, None),
#  ('Star Wars: The Fight Against the Dark Side', 2015, None, None),
#  ('Star Wars: The Ass Jedi!!', 2017, None, 'Animation'),
#  ("Star Wars FanFilm 'Lost with the Force'", 2018, None, 'Sci-Fi'),
#  ("'Star Wars: The Last Jedi' Trailer With Kevin Smith's Commentary", 2017, None, None),
#  ('Star Wars: Episode I - The Phantom Menace', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars: Episode VIII', 2015, None, None),
#  ('Star Wars: Family Ties', 2019, None, 'Sci-Fi'),
#  ('Star Wars Episode II: Attack of the Clones/Unfaithful/The New Guy', 2002, None, 'Talk-Show'),
#  ('Deception: Star Wars the Great Bluff', 2017, None, 'Documentary'),
# ...
#  ('Joss Whedon/Age of Ultron, Star Wars VII Cast, Suicide Squad Cast', 2015, None, 'Talk-Show'),
#  ('Star Wars Force Awakens, Attack on Titan, Batman vs. Superman', 2015, None, 'Comedy,Short'),
#  ('BigHead Star Wars: Anakin vs. Obi-wan', 2015, None, 'Comedy,Short'),
#  ('Jenna Busch Talks Batman, Star Wars and More', 2015, None, 'Talk-Show'),
#  ("5 Minor Actors from the Original Star Wars Trilogy You Didn't Realise Were in Everything", 2015, None, 'Comedy'),
#  ('Star Wars: The Fallen Brother', 2017, None, 'Action,Fantasy,Sci-Fi'),
#  ('Comedians on Star Wars: The Force Awakens', 2015, None, 'Comedy'),
#  ('Geekly News - STAR WARS, BATMOBILE, THANOS, and MORE!!!', 2014, None, 'News'),
#  ('Men vs. Movies Talk - Benicio Del Toro, STAR WARS VIII? The GOOD DINOSAUR Brings Our Childhood Home', 2015, None, None),
#  ('Men vs. Movies Talk - New Star Wars Pictures, Black Panther Costume Revealed, Brian vs. Griffin', 2015, None, None),
#  ('Star Wars Commander', 2014, None, 'War'),
#  ('5 Star Wars Fan Theories Too Good to Not Be True', 2015, None, 'Comedy'),
#  ('Her Universe Behind the Scenes of Star Wars Photoshoot', 2015, None, 'Talk-Show'),
#  ('Henshin GN, Mortal Kombat X, Star Wars + Comics 1/14/15', 2015, None, 'Talk-Show'),
#  ('Star Wars Characters Arrested in Tranny Sex Sting', 2015, None, 'Comedy'),
#  ('Some Reasons Why We Love Star Wars', 2015, None, 'Talk-Show'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Comedy,News,Talk-Show'),
#  ('What Star Wars Character Would Win the Hunger Games?', 2015, None, 'Talk-Show'),
#  ('Is Luke EVIL in Star Wars: The Force Awakens?', 2015, None, 'Animation,Comedy,Talk-Show'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Family'),
#  ('Star Wars: Will the Force Awaken? - Frame by Frame', 2015, None, 'Comedy'),
#  ('StarCade: Episode 9 - The Star Wars Holiday Special (FINALE)', 2015, None, 'Comedy'),
#  ('Star Wars', 2008, None, 'Comedy'),
#  ('Introducing Your Significant Other to Star Wars', 2015, None, 'Comedy,Short'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Talk-Show'),
#  ('Top 10 Star Wars Characters', 2015, None, 'Comedy,Talk-Show'),
#  ('All Star Wars Characters Have Stupid Names', 2015, None, 'Comedy'),
#  ('Star Wars Special', 2015, None, None),
#  ('1983 Pt 3 - Star Wars Arcade, Mario Bros, Ultima III, War Games', 2014, None, 'Documentary'),
#  ('Star Wars Movie Knight', 2015, None, 'Comedy'),
#  ('Star Wars IV, V, VI > Happiness & Motivation', 2015, None, 'Talk-Show'),
#  ('Star Wars Arcade (Sega 32X)/Star Wars: Rebel Assault (Sega CD)', 2015, None, 'Comedy,Talk-Show'),
#  ('Star Wars: The Force Awakens Review', 2015, None, 'Comedy,News'),
#  ('How Star Wars Changed the World', 2015, None, 'Documentary'),
#  ('Star Wars Special', 2015, None, 'Talk-Show'),
#  ('Star Wars Plug and Play', 2015, None, 'Comedy,Sci-Fi'),
#  ('The Star Wars Holiday Special (FINALE)', 2015, None, 'Comedy,Sci-Fi'),
#  ('Star Wars: The Force Awakens', 2015, None, 'Comedy'),
#  ('Star Wars Galatic Battlegrounds Part 3', 2015, None, 'Talk-Show'),
#  ('Star Wars Jedi Knight: Jedi Academy', 2016, None, 'Talk-Show'),
#  ('Star Wars Origins: George Lucas Interview Episode One Spoof', 2016, None, 'Comedy,Short'),
#  ("AfterBuzz TV's Star Wars Rebels After Show", 2014, None, 'Talk-Show'),
#  ('Lego Star Wars EP 1', 2016, None, 'Talk-Show'),
#  ('Lego Star Wars Part 3', 2016, None, 'Talk-Show'),
#  ('Star Wars: Lethal Alliance', 2006, None, 'Action'),
#  ('6 Star Wars Characters Meet Their New Equivalents', 2016, None, 'Comedy'),
#  ('How Star Wars: The Force Awakens Should Have Ended', 2016, None, 'Animation,Comedy'),
#  ('Black People in Star Wars', 2015, None, 'Talk-Show'),
#  ('Star Wars Parody Infomercials', 2015, None, 'Comedy'),
#  ('Star Wars: Episode III Revenge of the Sith Recreated in Less than an Hour', 2016, None, 'Action,Adventure,Comedy'),
#  ('Star Wars: Shadows of the Empire', 2008, None, 'Comedy,History'),
#  ('Star Wars: Rogue Squadron', 2009, None, 'Comedy,History'),
#  ('Star Wars: Dark Forces', 2012, None, 'Comedy,History'),
#  ('Lego Star Wars: The Complete Saga', 2016, None, 'Comedy'),
#  ('Star Wars: The Force Awakens Rewind!', 2016, None, 'Comedy'),
#  ('Star Wars the Force Awakens Alternate HISHE', 2016, None, 'Animation,Comedy'),
#  ('Star Wars: The Force Awakens', 2016, None, 'Comedy'),
#  ('Did Fox Insult Star Wars Fans?', 2015, None, 'Talk-Show'),
#  ('Star Wars Movie Once a Year... Forever!?', 2015, None, 'Talk-Show'),
#  ('Star Wars: The Force Awakens Is Here!!', 2015, None, 'Talk-Show'),
#  ('Obi-Wan in Star Wars Episode 8?', 2016, None, 'Talk-Show'),
#  ('Star Wars Rogue One Trailer Impressions', 2016, None, 'Talk-Show'),
#  ('The Benefits of Camouflage: A Star Wars Story', 2016, None, 'Comedy,Musical,Mystery'),
#  ('The Selling of Star Wars', 2014, None, 'Comedy,Short'),
#  ('Durham Bulls Star Wars Night Promo', 2016, None, 'Fantasy'),
#  ('Star Wars: Battlefront II', 2017, None, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Galaxy of Heroes', 2015, None, 'Sci-Fi'),
#  ('Star Wars', 2016, None, 'Comedy'),
#  ('Star Wars Day', 2015, None, 'Documentary'),
#  ('Star Wars Again', 2015, None, 'Documentary'),
#  ('Chewbacca Mom, Rogue One Character Reveal, a Star Wars Birthday Party', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars Episode 4', 2012, None, 'Animation,Comedy'),
#  ('Star Wars Episode 5', 2012, None, 'Animation,Comedy'),
#  ('Star Wars Episode 6', 2012, None, 'Animation,Comedy'),
#  ('Lego Star Wars: Battle of the Bricks', 2016, None, 'Reality-TV'),
#  ('Star Wars: Rise of Kylo Ren', 2016, None, 'Sci-Fi,Short'),
#  ('Lego Star Wars', 2016, None, None),
#  ('Star Wars: Bloodline Book Review (Non Spoilers)', 2016, None, 'Talk-Show'),
#  ('Will There Be Episode 8 Footage at Star Wars Celebration?', 2016, None, 'Talk-Show'),
#  ('Rooster Teeth vs. Star Wars, Summer Fun at Skywalker Ranch, and More!', 2016, None, 'Sci-Fi,Short,Talk-Show'),
#  ('Star Wars Celebration Day 1 Report', 2016, None, 'Talk-Show'),
#  ('Star Wars Celebration Day 2 Report', 2016, None, 'Talk-Show'),
#  ('Star Wars Celebration Day 3 Report', 2016, None, 'Talk-Show'),
#  ('Star Wars - Underworld - A XXX Parody', 2016, 163, 'Adult,Adventure,Sci-Fi'),
#  ('Star Wars: The Legacy Revealed', 2007, 155, 'Documentary'),
#  ('Star Wars XXX: A Porn Parody', 2012, 152, 'Adult,Comedy,Sci-Fi'),
#  ("Empire of Dreams: The Story of the 'Star Wars' Trilogy", 2004, 151, 'Documentary,History,Sci-Fi'),
#  ('Star Wars: Qui-Gon Jinn II', 2010, 150, 'Action,Sci-Fi'),
#  ('The Farce Awakens: A Star Wars Cosplay Fetish Porn Parody', 2016, 149, 'Adult'),
#  ('Star Wars: Episode II - Attack of the Clones', 2002, 142, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Episode III - Revenge of the Sith', 2005, 140, 'Action,Adventure,Fantasy'),
#  ('Star Wars Begins: A Filmumentary', 2011, 139, 'Documentary'),
#  ('Star Wars: Episode I - The Phantom Menace', 1999, 136, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Episode VII - The Force Awakens', 2015, 136, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Episode VI - Return of the Jedi', 1983, 131, 'Action,Adventure,Fantasy'),
#  ('Star Wars: Qui-Gon Jinn III', 2010, 130, 'Action,Sci-Fi'),
#  ('Star Wars: Episode V - The Empire Strikes Back', 1980, 124, 'Action,Adventure,Fantasy'),
#  ("Star Wars Uncut: Director's Cut", 2012, 124, 'Action,Sci-Fi'),
#  ('Star Wars', 1977, 121, 'Action,Adventure,Fantasy'),
#  ('The Star Wars Comic Con 09 Spectacular', 2009, 120, 'News'),
#  ('Star Wars: Greatest Moments', 2015, 120, 'Documentary'),
#  ('Star Wars: The Force Unleashed', 2012, 116, 'Action,Adventure'),
#  ('Star Wars: Will of the Force - An Independent Homage Film', 2017, 110, 'Sci-Fi'),
#  ('Star Wars: Threads of Destiny', 2014, 110, 'Action,Adventure,Sci-Fi'),
#  ("Mr. Plinkett's The Star Wars Awakens Review", 2016, 105, 'Comedy,Talk-Show'),
#  ('Star Wars: The Clone Wars', 2008, 98, 'Action,Adventure,Animation'),
#  ('The Star Wars Holiday Special', 1978, 97, 'Adventure,Family,Musical'),
#  ('Star Wars Spoofs', 2011, 97, 'Comedy,Documentary,Sci-Fi'),
#  ("The Stars of 'Star Wars': Interviews from the Cast", 1999, 93, 'Documentary'),
#  ('Rogue One: A Star Wars Story - World Premiere', 2016, 89, 'Reality-TV,Sci-Fi'),
#  ('Star Wars: A Gay XXX Parody', 2016, 89, 'Adult,Sci-Fi'),
#  ('Level BackUp S07E15: Guardians of the Galaxy, Persona 5, SNES Mini, Star Wars Battlefront 2', 2017, 89, 'Comedy,News'),
#  ('Star Wars and Santa Tracking', 2015, 86, 'News,Talk-Show'),
#  ('Star Wars: Star Warriors', 2007, 84, 'Documentary'),
#  ('Star Wars: The Gay Awakens', 2017, 81, 'Adult'),
#  ('Youngblood #5/Star Wars 3-D #1', 2013, 77, 'Comedy,Sci-Fi'),
#  ('Star Wars: Revenge of the Myth', 2014, 75, 'Documentary,Mystery,Reality-TV'),
#  ("Star Wars FanFilm the Padawan III 'Darkness of the Republic'", 2017, 75, 'Sci-Fi'),
#  ('Star Wars: A Musical Journey', 2005, 71, 'Music'),
#  ('Star Wars: The Dark Empire', 2011, 70, 'Action,Adventure,Sci-Fi'),
#  ('Plastic Galaxy: The Story of Star Wars Toys', 2014, 70, 'Documentary,History,Sci-Fi'),
#  ("The Stories: The Making of 'Rogue One: A Star Wars Story'", 2017, 69, 'Documentary'),
#  ('Star Wars: The Force Unleashed', 2013, 69, 'Sci-Fi'),
#  ('La La Land/Rogue One: A Star Wars Story', 2016, 68, 'Comedy,Talk-Show'),
#  ('Star Wars Heroes & Villains', 2005, 68, 'Documentary'),
#  ("From 'Star Wars' to 'Jedi': The Making of a Saga", 1983, 65, 'Documentary'),
#  ("The Unauthorized 'Star Wars' Story", 1999, 63, 'Documentary,Sci-Fi'),
#  ('Bob Wilkins Star Wars', 2015, 62, 'Documentary,Horror,Sci-Fi'),
#  ('Star Wars: The Magic & the Mystery', 1997, 60, 'Documentary'),
#  ('The Official Star Wars Fan Film Awards', 2002, 60, 'Documentary'),
#  ('When Star Wars Ruled the World', 2004, 60, 'Documentary'),
#  ('Star Wars: Underworld', 2018, 60, 'Action,Adventure,Drama'),
#  ('Call of the Jedi: A Star Wars Story', 2017, 60, 'Sci-Fi'),
#  ("You Can Draw 'Star Wars'", 2007, 60, 'Documentary'),
#  ('Star Wars: Music by John Williams', 1980, 59, 'Documentary'),
#  ('Star Wars: Episode I - The Phantom Menace - Webisodes', 2001, 58, 'Documentary'),
#  ("The Mythology of 'Star Wars'", 2000, 57, 'Documentary'),
#  ('Star Wars: Origins II: The Rising', 2011, 52, 'Action,Adventure,Sci-Fi'),
#  ('Phineas and Ferb Star Wars', 2014, 51, 'Action,Animation,Comedy'),
#  ("Hollywood's Master of Myth: Joseph Campbell - The Force Behind Star Wars", 1999, 50, 'Documentary'),
#  ('Star Wars: Qui-Gon Jinn', 2009, 50, 'Sci-Fi'),
#  ("The Making of 'Star Wars'", 1977, 50, 'Documentary'),
#  ('Star Wars: Revelations', 2005, 47, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars', 1998, 47, 'Documentary,History'),
#  ("'Star Wars': Feel the Force", 2005, 46, 'Documentary'),
#  ('Star Wars: A Galaxy in Darkness', 2009, 46, 'Adventure,Drama,Sci-Fi'),
#  ('From Star Wars to Star Wars: The Story of Industrial Light & Magic', 1999, 45, 'Documentary'),
#  ('The Untitled Star Wars Mockumentary', 2003, 45, 'Comedy'),
#  ('Star Wars: The Force Unleashed II', 2014, 45, 'Sci-Fi'),
#  ('Star Wars: The Myths Strike Back', 2015, 45, 'Documentary,Mystery,Reality-TV'),
#  ('Robot Chicken: Star Wars Episode III', 2010, 45, 'Animation,Comedy,Sci-Fi'),
#  ('Star Wars: The Dark Reckoning', 2017, 45, 'Sci-Fi'),
#  ('Star Wars Tech', 2007, 44, 'Documentary'),
#  ('The Star Wars Holiday Special (FOR REAL)', 2014, 44, 'Comedy'),
#  ('The Star Wars Holiday Special', 2014, 43, 'Comedy'),
#  ('The Cast of Star Wars: The Force Awakens', 2015, 43, 'Comedy,Music,Talk-Show'),
#  ('Star Wars: The Force Awakens', 2015, 42, 'Comedy,Talk-Show'),
#  ('Star Wars Forever', 2012, 42, 'Reality-TV'),
#  ('Star Wars', 2016, 42, None),
#  ('Reactions to Star Wars!', 2015, 40, 'Talk-Show'),
#  ('Star Wars: Battlefront', 2015, 40, 'Comedy'),
#  ('Star Wars: Episode I - The Phantom Menace - Behind the Scenes', 2001, 40, 'Documentary'),
#  ('The Force Awakens and Star Wars Formula: Analyzed Movie Review', 2016, 38, None),
#  ('Dark Awakening: A Star Wars Fan Film', 2015, 38, 'Action,Adventure,Fantasy'),
#  ('Star Wars: The Force Awakens', 2015, 35, 'Comedy,Talk-Show'),
#  ('Star Wars: Episode 0.5 - Dawn of the Sith', 2016, 34, 'Action,Adventure,Fantasy'),
#  ('SDI Star Wars', 1991, 33, 'Documentary,Short'),
#  ('Star Wars: The Old Republic', 2012, 31, 'Comedy'),
#  ('The Star Wars Holiday Special', 2015, 31, 'Comedy'),
#  ('Drunk Star Wars', 2016, 30, 'Comedy'),
#  ('Bizarre Star Wars', 2012, 30, 'Horror,Sci-Fi'),
#  ('Robot Chicken: Star Wars', 2007, 30, 'Animation,Comedy,Sci-Fi'),
#  ('Episodio 101: Especial Star Wars II', 2014, 30, 'Comedy,History'),
#  ('Star Wars: Evolution of the Lightsaber Duel', 2015, 30, 'Documentary'),
#  ('Star Wars Returns', 2001, 30, 'Documentary,Short'),
#  ('Star Wars & Jewish JJ Abrams', 2014, 28, 'Talk-Show'),
#  ('Star Wars: Darkness Unleashed', 2007, 28, 'Sci-Fi,Short'),
#  ('Star Wars X-Wing', 2013, 28, 'Comedy,Game-Show'),
#  ('Star Wars Pathways: Chapter II - Path of Deceit', 2012, 26, 'Sci-Fi,Short'),
#  ('Fake Star Wars Toys', 2015, 25, 'Comedy,Reality-TV,Talk-Show'),
#  ('Tira: A Star Wars Fan Film', 2017, 25, None),
#  ('The Stars of Star Wars', 1980, 24, 'Comedy,Family,Music'),
#  ('Star Wars: Droids', 1985, 24, 'Adventure,Animation,Family'),
#  ('Robot Chicken: Star Wars Episode II', 2008, 24, 'Animation,Comedy,Sci-Fi'),
#  ('Rogue One: A Star Wars Story', 2016, 23, 'Comedy'),
#  ('Star Wars: Shortened!', 2006, 23, 'Sci-Fi,Short'),
#  ('Star Wars', 2012, 23, 'Comedy,Family'),
#  ('Star Wars: The Clone Wars', 2008, 23, 'Action,Adventure,Animation'),
#  ('Episodio 100: Especial Star Wars', 2014, 23, 'Comedy,History'),
#  ('Lego Star Wars: The Freemaker Adventures', 2016, 23, 'Action,Animation,Comedy'),
#  ('The Star Wars #1', 2015, 23, 'Comedy,Sci-Fi'),
#  ('Star Wars Stormtrooper/Mustang Motorcycle', 2013, 22, 'Reality-TV'),
#  ('Star Wars: Rebels', 2014, 22, 'Action,Adventure,Animation'),
#  ("Star Wars: Smuggler's Run", 2013, 22, 'Action,Sci-Fi,Short'),
#  ('Star Wars Games', 2011, 22, 'Comedy'),
#  ('Lego Star Wars: The Padawan Menace', 2011, 22, 'Animation,Family,Fantasy'),
#  ('Top 11 GOOD Things from the Star Wars Prequels', 2014, 22, 'Comedy'),
#  ('(SPOILERS) Star Wars: The Force Awakens Review', 2015, 22, 'Talk-Show'),
#  ('Lego Star Wars: The Empire Strikes Out', 2012, 22, 'Action,Animation,Comedy'),
#  ('Star Wars: The Force Awakens', 2015, 21, 'Comedy'),
#  ('The Making of Star Wars: In Concert', 2009, 21, 'Documentary'),
#  ('Star Wars Legends: Legacy of the Force', 2015, 20, 'Sci-Fi,Short'),
#  ('Star Wars Pathways: Chapter I - Path of Betrayal', 2006, 20, 'Sci-Fi,Short'),
#  ('Star Wars: The Clone Wars Preview Special', 2008, 20, 'Action,Adventure,Animation'),
#  ('Atop the Fourth Wall: Star Wars #1-#7', 2013, 19, 'Comedy'),
#  ('The Star Wars #2', 2015, 19, 'Comedy,Sci-Fi'),
#  ("The Characters of 'Star Wars'", 2004, 19, 'Documentary,Short'),
#  ('The Friend Zone: Star Wars Ep2 - Auralnauts', 2013, 18, 'Comedy,Short'),
#  ('Star Wars', 2015, 18, 'Game-Show'),
#  ("An Idiot's Array: A Star Wars Short Story", 2017, 18, 'Action,Adventure,Sci-Fi'),
#  ('Star Wars at the BBC', 2015, 17, 'Documentary,Sci-Fi,Short'),
#  ('Star Wars Battlefront - Hard West', 2015, 17, 'Comedy'),
#  ('Exile: A Star Wars Fan Film', 2016, 16, 'Action,Sci-Fi,Short'),
#  ('Star Wars: Emergence', 2016, 16, 'Drama,Short'),
#  ('The Star Wars #3', 2016, 16, 'Comedy,Sci-Fi'),
#  ('The Star Wars Holiday Special: PWN #11', 2016, 16, 'Comedy,Talk-Show'),
#  ('Star Wars: The Renegades Duty', 2015, 15, 'Action,Animation,Fantasy'),
#  ('Star Wars Theme/Cantina Band by Meco', 2015, 15, 'Documentary,History,Music'),
#  ('Star Wars: Vengeance', 2016, 15, 'Action,Drama,Sci-Fi'),
#  ('Not Another Star Wars Update!', 2015, 15, 'Comedy,Talk-Show'),
#  ('Star Wars: Clone Wars', 2003, 15, 'Action,Adventure,Animation'),
#  ('Star Wars or Bust', 1999, 15, 'Documentary,Sci-Fi,Short'),
#  ('Star Wars: DIY Cosplay', 2015, 14, 'Action,Short'),
#  ('119: Star Wars Episode III: Revenge of the Script', 2015, 14, None),
#  ('Star Wars: The Force Awakens', 2015, 14, 'Comedy'),
#  ('Jedi Party: Star Wars Ep1 - Auralnauts', 2013, 14, 'Comedy,Short'),
#  ('Lego Star Wars: Battle of Sebiris', 2016, 14, 'Action,Adventure,Animation'),
#  ('The Star Wars #4', 2017, 14, 'Comedy,Sci-Fi'),
#  ("The Force Is with Them: The Legacy of 'Star Wars'", 2004, 13, 'Documentary,Short'),
#  ...]

# %%
psql -U postgres -d imdb1 <<EOF

-- or you may write your statement here
EOF

# %% [markdown]
# **SOLUTION 2:**

# %%
pass1=
encrypt="U2FsdGVkX19laVXVoXmMBKtRHvrfSnfkNJhynaSpFpRrOpeoRykDziSFF1AiVIWA 0N1ai35oqn6zxx1/lh/qWM6/aMQXEGk/Njoj7TPIg63cInhl/ly/8Ho0Gl3Wop2m CVFRBWtZuzRP7RhyRxNFR8EjA2pSje6RkVrwQrrRTRK2s8cmEZPgt+8wgrLCo33A UgCHxIQ4T3el7GtPsmb7LKzjItZvROAdcXbIJX1Ekj6tJT9YWbIknKTtETtaHzOk OgTURnjlpIH5bYsB1Q6E5l/B/g6FjqZ3Y5lUDs5qxhY="
solution=$(echo $encrypt | openssl enc -md sha256 -aes-128-cbc -a -d -salt -pass pass:$pass1 2> /dev/null)
echo "$solution"; echo
for l in "$solution"; do eval "${l}"; done

# %% [markdown]
# Note that, unless we explicitly tell SQL server to exclude NA values, it also returns NA values

# %% [markdown]
# Now, back to the Godfather trilogy...
#
# We still have comedy. Now we enhance the WHERE clause so that comedy is also excluded
#
# Note that we can either alter regex as case insensitive (?i) or make the regex operator case insensitive (~*):

# %%
%%sql

SELECT tconst, originaltitle, startyear, runtimeminutes, genres
  FROM title_basics
  WHERE originaltitle ~ '.*Godfather.*Part.*'
	AND genres ~ '(?i)drama'
	AND NOT genres ~* 'comedy'
  ORDER BY runtimeminutes;

# %% [markdown]
# That's ok but we only want titles from the original trilogy last of which was screened in 1990

# %%
%%sql

SELECT tconst, originaltitle, startyear, runtimeminutes, genres
  FROM title_basics
  WHERE originaltitle ~ '.*Godfather.*Part.*'
	AND genres ~ '(?i)drama'
	AND NOT genres ~ '(?i)comedy'
	AND startyear <= 1990
  ORDER BY runtimeminutes;

# %% [markdown]
# There, we have what we want for further queries

# %% [markdown]
# **EXERCISE 3:**
#
# - Select original title and startyear
# - From title_basics table
# - Those records in which originaltitle includes Star Wars
# - Genres include Sci-Fi
# - And not drama
# - Runtimeminutes shorter than 60 or longer than 150
# - Sort by runtimes minutes and startyear

# %%
%%sql
SELECT originaltitle, startyear
  FROM title_basics
  WHERE originaltitle ~ '.*Star Wars.*Part.*'
	AND genres ~ '(?i)Sci-Fi'
	AND NOT genres ~ '(?i)drama'
	AND (runtimeminutes < 60 or runtimeminutes>150)
  ORDER BY runtimeminutes, startyear
# Out:
#  * postgres://postgres@localhost/imdb2
# 0 rows affected.
# []

# %%
psql -U postgres -d imdb1 <<EOF

-- or you may write your statement here
EOF

# %% [markdown]
# **SOLUTION 3:**

# %%
pass1=4021
encrypt="U2FsdGVkX19EW9F4b4zlMMSvkx1iNjeL5AghD78cx7qqV1OJWShAL5DzI9kivtGh GTxPd+hVCPRscMqSPBWr34XzfQXvktM8Z41FIEKTu/LJ7/2Clrxubh6Zl6fb5j79 9KPMRdRcpRNghOkmvqQVSL5vLPlQPDipQRG6Zp2HEH0lavcTmobC5b9uksKCTlFO srC8sGsq9ssvqGeYgn9Lqdw+O5sWvlEI5VeKtRIZMxCPSlZnKTWuDlCeWFzbw6cC GOq4tx2aLhrDdcNea6Y7R2j+y98k6E5zxW22YMNr6QFkmeHmjbvjQi5q5vYiZcka oIIn5pcoE7pKe4X9ppDqFVsb5EgqiAa+so2dIenZC4uPVlZKzT2YU1xpg53laFp0 EiQVWd/NXRMl6fpBWVahBnl6pE7wSISke8ZovjPcwAE="
solution=$(echo $encrypt | openssl enc -md sha256 -aes-128-cbc -a -d -salt -pass pass:$pass1 2> /dev/null)
echo "$solution"; echo
for l in "$solution"; do eval "${l}"; done
# Out:
# psql -U postgres -d imdb2 <<EOF
# SELECT originaltitle, startyear, runtimeminutes, genres
#   FROM title_basics
#   WHERE originaltitle ~ 'Star.*Wars'
# 	AND genres ~ '(?i)Sci-Fi'
# 	AND NOT genres ~ '(?i)drama'
# 	AND (runtimeminutes < 60
#          OR runtimeminutes > 150)
#   ORDER BY runtimeminutes, startyear;
# EOF
#
#                                   originaltitle                                  | startyear | runtimeminutes |           genres
# ---------------------------------------------------------------------------------+-----------+----------------+----------------------------
#  Star Wars Gangsta Rap 2                                                         |      2007 |              3 | Comedy,Sci-Fi,Short
#  Star Wars: The Last Jedi                                                        |      2008 |              3 | Action,Fantasy,Sci-Fi
#  Songs from the Sarlacc: Star Wars 360° VR                                       |      2016 |              3 | Musical,Sci-Fi,Short
#  Lego Star Wars: Revenge of the Brick                                            |      2005 |              5 | Animation,Comedy,Sci-Fi
#  Star Wars & Dragon Ball Z                                                       |      2007 |              5 | Sci-Fi,Short
#  Lego Star Wars: The Quest for R2-D2                                             |      2009 |              5 | Animation,Comedy,Sci-Fi
#  Lego Star Wars: Bombad Bounty                                                   |      2010 |              5 | Animation,Comedy,Sci-Fi
#  Star Wars I: The Phantom Menace in the Playroom                                 |      2012 |              5 | Adventure,Comedy,Sci-Fi
#  Star Wars Speed Dating                                                          |      2013 |              5 | Comedy,Sci-Fi,Short
#  Star Wars: Vengeance Rising                                                     |      2015 |              5 | Sci-Fi
#  Star Wars: Amulet of Urlon                                                      |      2016 |              5 | Sci-Fi,Short
#  Identity Thieves: A Star Wars Fan Film                                          |      2016 |              5 | Adventure,Fantasy,Sci-Fi
#  Star Wars: Generations                                                          |      2016 |              5 | Family,Sci-Fi,Short
#  Star Wars: Phantoms of Fate                                                     |      2016 |              5 | Sci-Fi,Short
#  Star Wars: Connections                                                          |      2002 |              6 | Sci-Fi,Short
#  Star Wars Droids: The Jawa Adventure                                            |      2012 |              6 | Adventure,Sci-Fi,Short
#  Logan Must Make Star Wars                                                       |      2014 |              6 | Comedy,Sci-Fi,Short
#  Star Wars: Force of Evil                                                        |      2015 |              6 | Sci-Fi,Short
#  The Star Wars Show                                                              |      2016 |              7 | Sci-Fi,Short,Talk-Show
#  Star Wars: Wraith Squadron                                                      |      2017 |              7 | Sci-Fi,Short
#  Star Wars: Aeon                                                                 |      2016 |              8 | Action,Fantasy,Sci-Fi
#  Star Wars: Episode III - The Return of Darth Vader                              |      2004 |              9 | Documentary,Sci-Fi,Short
#  Boba Fett's Untold Story: Star Wars Fan Film                                    |      2015 |              9 | Sci-Fi,Short
#  My Dark Side and My Light Side Meet in a Bar to Discuss the New Star Wars Movie |      2015 |              9 | Comedy,Fantasy,Sci-Fi
#  Duncan Jones, Best of Star Wars Day and Celebration News                        |      2016 |              9 | Sci-Fi,Short,Talk-Show
#  Star Wars: Episodio Pi - Sithspotting                                           |      2002 |             11 | Action,Comedy,Sci-Fi
#  Star Wars: Extinction                                                           |      2006 |             11 | Action,Fantasy,Sci-Fi
#  Star Wars: The Holo Xperience                                                   |      2013 |             11 | Sci-Fi,Short
#  Star Wars: Wrath of the Mandalorian                                             |      2008 |             12 | Action,Sci-Fi,Short
#  The StarWars Adventures: Project Blackwing                                      |      2016 |             13 | Sci-Fi
#  The StarWars Adventures                                                         |      2016 |             13 | Sci-Fi
#  The Star Wars #4                                                                |      2017 |             14 | Comedy,Sci-Fi
#  Star Wars or Bust                                                               |      1999 |             15 | Documentary,Sci-Fi,Short
#  The Star Wars #3                                                                |      2016 |             16 | Comedy,Sci-Fi
#  Exile: A Star Wars Fan Film                                                     |      2016 |             16 | Action,Sci-Fi,Short
#  Star Wars at the BBC                                                            |      2015 |             17 | Documentary,Sci-Fi,Short
#  An Idiot's Array: A Star Wars Short Story                                       |      2017 |             18 | Action,Adventure,Sci-Fi
#  The Star Wars #2                                                                |      2015 |             19 | Comedy,Sci-Fi
#  Star Wars Pathways: Chapter I - Path of Betrayal                                |      2006 |             20 | Sci-Fi,Short
#  Star Wars Legends: Legacy of the Force                                          |      2015 |             20 | Sci-Fi,Short
#  Star Wars: Smuggler's Run                                                       |      2013 |             22 | Action,Sci-Fi,Short
#  Star Wars: Shortened!                                                           |      2006 |             23 | Sci-Fi,Short
#  The Star Wars #1                                                                |      2015 |             23 | Comedy,Sci-Fi
#  Robot Chicken: Star Wars Episode II                                             |      2008 |             24 | Animation,Comedy,Sci-Fi
#  Star Wars Pathways: Chapter II - Path of Deceit                                 |      2012 |             26 | Sci-Fi,Short
#  Star Wars: Darkness Unleashed                                                   |      2007 |             28 | Sci-Fi,Short
#  Robot Chicken: Star Wars                                                        |      2007 |             30 | Animation,Comedy,Sci-Fi
#  Bizarre Star Wars                                                               |      2012 |             30 | Horror,Sci-Fi
#  Robot Chicken: Star Wars Episode III                                            |      2010 |             45 | Animation,Comedy,Sci-Fi
#  Star Wars: The Force Unleashed II                                               |      2014 |             45 | Sci-Fi
#  Star Wars: The Dark Reckoning                                                   |      2017 |             45 | Sci-Fi
#  Star Wars: Revelations                                                          |      2005 |             47 | Action,Adventure,Sci-Fi
#  Star Wars: Qui-Gon Jinn                                                         |      2009 |             50 | Sci-Fi
#  Star Wars: Origins II: The Rising                                               |      2011 |             52 | Action,Adventure,Sci-Fi
#  Empire of Dreams: The Story of the 'Star Wars' Trilogy                          |      2004 |            151 | Documentary,History,Sci-Fi
#  Star Wars XXX: A Porn Parody                                                    |      2012 |            152 | Adult,Comedy,Sci-Fi
#  Star Wars - Underworld - A XXX Parody                                           |      2016 |            163 | Adult,Adventure,Sci-Fi
# (57 rows)

# %% [markdown]
# We can represent the runtimeminutes filter with a BETWEEN condition:

# %%
pass1=
encrypt="U2FsdGVkX19j4SGpgZW4DfLWs5VI0x/jrCAtXCRUsr/jp8yxZsrbRXmbN22UpfB1 kvsy3i51vT10+p4ItE9XGOXlVEVhgsvW+Zanf4+ZKyTvNkUOBdSydvElBTJM1VIZ HnB8JISJeG/kipPG2LnGuMLdhCxqL/yHtuQDK5uPF74x+Mpm9BQsg5E0MVHWulB1 6CPkEnugOjDm1pPt30v86LSXG8LvFq7ArlQd57BTBJE6cTo7PR3vNbV6z/9MLLaK kCIADJaGtGT+D8fhhUNolgG7Zv/t5uaurtd3xvGt96x7MmRuoHtfGb4KzfoVSZDC ASGVAbX2a1hiObKGrHB4CSFhg3zu748kAivxAjqMqdXb/m9WtlZAUvqiALPTSm13 pf4NqjJiGeidG2GAxSyhXHOJnqCmhH5wWKJwDavw3kc="
solution=$(echo $encrypt | openssl enc -md sha256 -aes-128-cbc -a -d -salt -pass pass:$pass1 2> /dev/null)
echo "$solution"; echo
for l in "$solution"; do eval "${l}"; done

# %% [markdown]
# ## A discussion on regex

# %% [markdown]
# Note that regex or regexp (regular expressions) is a domain specific querying language
#
# And a very powerful tool for mining, querying and manipulating textual data
#
#
# And is worth spending effort to learn if you deal with textual data

# %% [markdown]
# This tutorial is a good starting point:
#
# http://www.regular-expressions.info/tutorial.html

# %% [markdown]
# And this site if for testing regex patterns on some text:
#
# https://regex101.com/

# %% [markdown]
# And this competition website if good for progressing in regex and having fun at the same time:
#
# https://regexcrossword.com/

# %% [markdown]
# ## DISTINCT

# %% [markdown]
# Let's say we want to get the unique valued rows from the result of a query, as we did in the first session.
#
# Get unique genres from genres_molten:

# %%
%%sql

SELECT DISTINCT genres
FROM genres_molten;

# %% [markdown]
# ## GROUP BY, HAVING and aggregate functions

# %% [markdown]
# Let's get the average runtime and count of movies including Godfather by decades:

# %%
%%sql

SELECT (startyear / 10) * 10 as decade, avg(runtimeminutes) as runavg, count(*)
  FROM title_basics
  WHERE originaltitle ~ 'Godfather'
  GROUP BY decade;
# Out:
#  * postgres://postgres@localhost/imdb2
# 11 rows affected.
# [(1910, None, 6),
#  (1930, Decimal('81.0000000000000000'), 1),
#  (1940, Decimal('106.0000000000000000'), 1),
#  (1950, Decimal('30.0000000000000000'), 1),
#  (1960, Decimal('28.3333333333333333'), 4),
#  (1970, Decimal('120.5555555555555556'), 12),
#  (1980, Decimal('33.3333333333333333'), 8),
#  (1990, Decimal('178.0000000000000000'), 25),
#  (2000, Decimal('41.7500000000000000'), 52),
#  (2010, Decimal('52.1935483870967742'), 77),
#  (None, None, 10)]

# %% [markdown]
# Now let's filter records on a condition including an aggregated field such as, filter for decades with average runtimeminutes greater than 80:
#
# Note that we can define an alias for a calculated field or a table with a long name:

# %%
%%sql

SELECT (startyear / 10) * 10 as decade, avg(runtimeminutes) as runavg, count(*)
  FROM title_basics
  WHERE originaltitle ~ 'Godfather'
  GROUP BY decade
  HAVING avg(runtimeminutes) > 80;
# Out:
#  * postgres://postgres@localhost/imdb2
# 4 rows affected.
# [(1930, Decimal('81.0000000000000000'), 1),
#  (1940, Decimal('106.0000000000000000'), 1),
#  (1970, Decimal('120.5555555555555556'), 12),
#  (1990, Decimal('178.0000000000000000'), 25)]

# %% [markdown]
# **EXERCISE 4:**
#
# - Select 5 year starting position of startyear, minimum runtimeminutes and maximum runtime minutes
# - From title_basics
# - Group by 5 year periods
# - And filter for groups where max runtime minutes of the group is less than 140 and the five year periods is not NULL
# - Order by fiveyear periods

# %%
%%sql
SELECT (startyear / 5) * 5 as five_years, min(runtimeminutes) as run_min, max(runtimeminutes) as run_max
  FROM title_basics
  WHERE originaltitle ~ 'Star Wars'
  GROUP BY five_years
  HAVING max(runtimeminutes) < 140 and (startyear / 5) * 5 IS NOT NULL 
  order by five_years
# Out:
#  * postgres://postgres@localhost/imdb2
# 5 rows affected.
# [(1975, 50, 121),
#  (1980, 1, 131),
#  (1985, 24, 24),
#  (1990, 2, 33),
#  (1995, 15, 136)]

# %%
psql -U postgres -d imdb1 <<EOF

-- or you may write your statement here
EOF

# %% [markdown]
# **SOLUTION 4:**

# %%
pass1=2854
encrypt="U2FsdGVkX1/4Df2hQ29wd6U/qzTn4z2MYoMx8tNYA2nR2w2vVDspxUYSNdg0YNNa oWXZ3p0SSjLU87USaZTdAryMwF51trIJyFebz7jjIgbCupCqzUnBxYUTGvFT32Ic 7qcaiyRWNDZ4UHrgcosBvZbAoDn7po8swpZFlfE3Zp7p3pc0LMCjurxsKCSW1EfA cD88pVWBXcjQLrFiIvldXHB0gaiKJeFFq6o4n2uqIlYjT21A6tDuao3aVtRPMQ84 hlyqsAvsxWE1RRLeSmjgr4nsDn2HtM+/71GR5widmUJgh2SmTlFbFpore1I0lezU WKhENNO+4VOOjBJQrdEkC47NXkz2AlNQPV7aHcpiumdzjvvGtwdM90UogFIndHKl pt6VMU5mAh9iW8HrYXTbYvJEJ5VS8dZ8AZdSi/j3ipZqag+qkuIKiFmRZdhJE4iP"
solution=$(echo $encrypt | openssl enc -md sha256 -aes-128-cbc -a -d -salt -pass pass:$pass1 2> /dev/null)
echo "$solution"; echo
for l in "$solution"; do eval "${l}"; done
# Out:
# psql -U postgres -d imdb2 <<EOF
# SELECT (startyear / 5) * 5 as fiveyears, min(runtimeminutes) as mintime, max(runtimeminutes) as maxtime
#   FROM title_basics
#   WHERE originaltitle ~ 'Star.*Wars'
#   GROUP BY fiveyears
#   HAVING max(runtimeminutes) < 140
#     AND (startyear / 5) * 5 IS NOT NULL
#   ORDER BY fiveyears;
# EOF
#
#  fiveyears | mintime | maxtime
# -----------+---------+---------
#       1975 |      50 |     121
#       1980 |       1 |     131
#       1985 |      24 |      81
#       1990 |       2 |      33
#       1995 |      15 |     136
# (5 rows)

# %% [markdown]
# ## JOINs, subqueries and aliases

# %% [markdown]
# Now we would like to join titles from the original Godfather trilogy last of which was screened in 1990 with id's of principal cast

# %%
%%sql

SELECT tb.tconst, tb.originaltitle, tb.startyear,
    tb.runtimeminutes, tb.genres, tp.principalcast
    FROM title_basics tb
    LEFT JOIN title_principals_melt tp ON tb.tconst=tp.tconst
  WHERE tb.originaltitle ~ 'Godfather.*Part'
	AND tb.genres ~ '(?i)drama'
	AND NOT tb.genres ~ '(?i)comedy'
	AND tb.startyear <= 1990
  ORDER BY tb.runtimeminutes;
# Out:
#  * postgres://postgres@localhost/imdb2
# 20 rows affected.
# [('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0000199'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0000338'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0000412'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0000473'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0001735'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0178874'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0296636'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0539794'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0701374'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0932336'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000065'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000134'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000199'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000338'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000380'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000473'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0539794'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0548943'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0701374'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0932336')]

# %% [markdown]
# We could also get the same result by running a subquery
#
# A subquery is a query with a alias (a name) and executed inside another query
#
# Using the alias, the subquery results can be treated as a separate table

# %%
%%sql

SELECT subq1.*, tp.principalcast
  FROM
(
SELECT tconst, originaltitle, startyear, runtimeminutes, genres
  FROM title_basics
  WHERE originaltitle ~ 'Godfather.*Part'
	AND genres ~ '(?i)drama'
	AND NOT genres ~ '(?i)comedy'
	AND startyear <= 1990
  ORDER BY runtimeminutes
) subq1

LEFT JOIN title_principals_melt tp ON subq1.tconst=tp.tconst;
# Out:
#  * postgres://postgres@localhost/imdb2
# 20 rows affected.
# [('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0000199'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0000338'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0000412'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0000473'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0001735'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0178874'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0296636'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0539794'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0701374'),
#  ('tt0099674', 'The Godfather: Part III', 1990, 162, 'Crime,Drama', 'nm0932336'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000065'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000134'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000199'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000338'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000380'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0000473'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0539794'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0548943'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0701374'),
#  ('tt0071562', 'The Godfather: Part II', 1974, 202, 'Crime,Drama', 'nm0932336')]

# %% [markdown]
# You can find more information on subqueries:
#
# http://www.postgresqltutorial.com/postgresql-subquery/

# %% [markdown]
# Now let's do sth more complicated:
#
# - Starting with first option (not the subquery), let's make a three way join
# - First join titles and principal cast on title id's (tconst)
# - And then join principal cast and name basics on name id's (nconst)
# - Filter only for actors and actresses
# - And sort on first names (ascendng) then title years

# %%
%%sql

SELECT tb.tconst, tb.originaltitle, tb.startyear, tb.runtimeminutes, tb.genres,
    tp.principalcast,
    nb.primaryname, nb.birthyear, nb.deathyear, nb.primaryprofession

FROM title_basics tb
LEFT JOIN title_principals_melt tp ON tb.tconst=tp.tconst
	LEFT JOIN name_basics nb ON tp.principalcast=nb.nconst

WHERE tb.originaltitle ~ 'Godfather.*Part'
	AND tb.genres ~ '(?i)drama'
	AND NOT tb.genres ~ '(?i)comedy'
	AND tb.startyear <= 1990
	AND nb.primaryprofession ~'actor|actress'

ORDER BY nb.primaryname, tb.startyear DESC;

# %% [markdown]
# When the column names are the same in a join, we can use USING as a shorthand:

# %%
%%sql

SELECT tb.tconst, tb.originaltitle, tb.startyear, tb.runtimeminutes, tb.genres,
    tp.principalcast,
    nb.primaryname, nb.birthyear, nb.deathyear, nb.primaryprofession

FROM title_basics tb
LEFT JOIN title_principals_melt tp USING (tconst)
	LEFT JOIN name_basics nb ON tp.principalcast=nb.nconst

WHERE tb.originaltitle ~ 'Godfather.*Part'
	AND tb.genres ~ '(?i)drama'
	AND NOT tb.genres ~ '(?i)comedy'
	AND tb.startyear <= 1990
	AND nb.primaryprofession ~'actor|actress'

ORDER BY nb.primaryname, tb.startyear DESC;

# %% [markdown]
# **EXERCISE 5:**
#
# List the living principal cast names in movies directed by Stanley Kubrick (nm0000040) in 1970's and 1980's. Report these columns:
# - Title of movie, staryear, genres and primaryname
#
# Use the following tables:
# - title_crew
# - title_basics
# - title_principals_melt
# - name_basics
#
# Follow this plan:
# - Left join title_crew to title_basics using common tconst field to combine directors with movie details
# - Left join to title_principals using common tconst field to combine director/movie details with pricipal cast
# - Left join to name_basics using the relation between principalcast and nconst fields to combine with the names of the principal cast
#
# - Filter for the director code in title_crew nm0000040
# - Filter for 1970's and 1980's startyear in title_basics
# - Filter for deathyear in name_basics being NULL
#
# Order by first startyear and then primaryname
#
#
# Hint:
# - Progress stepwise:
#     - First you may start with joining title_crew and title_basics (filtering for directors)
#     - And later for 1970's and 1980's
#     - After that, you may join with title_principals_melt and see the results.
#     - And last join with name_basics to add the names and filter for deathyear.
# -  And You can write your statement in pgcli so that you can leverage the smart completion feature (but copy here frequently)

# %%
%%sql
SELECT tb.tconst, tb.originaltitle, tb.startyear, tb.runtimeminutes, tb.genres,
    tp.principalcast,
    nb.primaryname, nb.birthyear, nb.deathyear, nb.primaryprofession

FROM title_basics tb
LEFT JOIN title_principals_melt tp USING (tconst)
	LEFT JOIN name_basics nb ON tp.principalcast=nb.nconst

WHERE tb.originaltitle ~ 'Godfather.*Part'
	AND tb.genres ~ '(?i)drama'
	AND NOT tb.genres ~ '(?i)comedy'
	AND tb.startyear <= 1990
	AND nb.primaryprofession ~'actor|actress'

ORDER BY nb.primaryname, tb.startyear DESC;

# %%
psql -U postgres -d imdb1 <<EOF

-- or you may write your statement here
EOF

# %% [markdown]
# **SOLUTION 5:**

# %%
pass1=4824
encrypt="U2FsdGVkX19HQOMAJZjspC7Lo2IESEwcPIhqrmWzsghnzubsh60z3xkXKld7pEvy jx2MuhEAETgwH32Ukr4XDtAZdDU07wpXT1BrTMNzdO917ZlsPbhReM76GIfN5Adg lotWy7O9hdmTRGxA5+izGCLqgB0VwbH0PyMBxER5SdAvhWNpziDTOJnPqH1lZOi/ eDuqBMYzNELuJJiKDjv73FrcOTYydu6LYKdyglg2bCa6rNJHGSBAmnBJnUTRcgNN Ms7P9JrzIBxUvJ5HlSknLFvlz53OhE/JrtCQV59FMtVaZ3jfEOdTcd35RYLBWFbw Fd4Cl4O+rkrD7Abs15sk0wwu4dDz/jTzflnOV6E88bB5ODavWH+UdnoOzmyqLkS1 8Rwxd9E502uaAnfcykE2inLKncsJPFvVpHvT/OlAGK45TZ2QJhpw2zv4ecgL+bOb nugWFHOixq4Ly28mnuqCMqy200Nh4ZfiWi+mxiKv4ZumuZJb1zzVQWPGEP1IB5v9 B6XFOK+cnznjbmAnz5FEY4zo/9DWqO2iqK//xrWswOXFZSpZYCyQizwybPs9gI6S ianRCR9Z66/6Zk8R0kgzYw=="
solution=$(echo $encrypt | openssl enc -md sha256 -aes-128-cbc -a -d -salt -pass pass:$pass1 2> /dev/null)
echo "$solution"; echo
for l in "$solution"; do eval "${l}"; done
# Out:
# psql -U postgres -d imdb2 <<EOF
# SELECT tb.originaltitle, tb.startyear, tb.genres, nb.primaryname
#
# FROM title_crew tc
# LEFT JOIN title_basics tb USING (tconst)
# 	LEFT JOIN title_principals_melt tp USING (tconst)
#         LEFT JOIN name_basics nb ON tp.principalcast=nb.nconst
#
# WHERE tc.directors ~ 'nm0000040'
# 	AND tb.startyear / 10 BETWEEN 197 AND 198
#     AND nb.deathyear IS NULL
#
# ORDER BY tb.startyear, nb.primaryname;
# EOF
#
#    originaltitle    | startyear |         genres          |    primaryname
# --------------------+-----------+-------------------------+-------------------
#  A Clockwork Orange |      1971 | Crime,Drama,Sci-Fi      | Malcolm McDowell
#  Barry Lyndon       |      1975 | Adventure,Drama,History | Hardy Krüger
#  Barry Lyndon       |      1975 | Adventure,Drama,History | Marisa Berenson
#  Barry Lyndon       |      1975 | Adventure,Drama,History | Ryan O'Neal
#  Barry Lyndon       |      1975 | Adventure,Drama,History | Tony Lawson
#  The Shining        |      1980 | Drama,Horror            | Danny Lloyd
#  The Shining        |      1980 | Drama,Horror            | Diane Johnson
#  The Shining        |      1980 | Drama,Horror            | Jack Nicholson
#  The Shining        |      1980 | Drama,Horror            | Rachel Elkind
#  The Shining        |      1980 | Drama,Horror            | Shelley Duvall
#  The Shining        |      1980 | Drama,Horror            | Stephen King
#  The Shining        |      1980 | Drama,Horror            | Wendy Carlos
#  Full Metal Jacket  |      1987 | Drama,War               | Adam Baldwin
#  Full Metal Jacket  |      1987 | Drama,War               | Douglas Milsome
#  Full Metal Jacket  |      1987 | Drama,War               | Martin Hunter
#  Full Metal Jacket  |      1987 | Drama,War               | Matthew Modine
#  Full Metal Jacket  |      1987 | Drama,War               | R. Lee Ermey
#  Full Metal Jacket  |      1987 | Drama,War               | Vincent D'Onofrio
#  Full Metal Jacket  |      1987 | Drama,War               | Vivian Kubrick
# (19 rows)

# %% [markdown]
# Unfortunately, R. Lee Ermey who starred in one of the definitive scenes in movie history (opening scene of Full Metal Jacket) and was still alive in 2017 (the data this version of the database was last updated) passed away in 2018.

# %% [markdown]
# ## Insert, update and delete records

# %% [markdown]
# ### Insert a record

# %% [markdown]
# Now let's say we want to add a new record to title_ratings table
#
# First let's switch to imdb1 table to leave imdb2 intact

# %%
%sql postgres://postgres@localhost/imdb1
# Out:
# (psycopg2.OperationalError) FATAL:  database "imdb1" does not exist
#  (Background on this error at: http://sqlalche.me/e/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys(['postgres://postgres@localhost/imdb2'])

# %%
%%sql
SELECT *
FROM title_ratings
LIMIT 5;
# Out:
#  * postgres://postgres@localhost/imdb2
# 5 rows affected.
# [('tt0000001', Decimal('5.8'), 1306),
#  ('tt0000002', Decimal('6.5'), 149),
#  ('tt0000003', Decimal('6.6'), 885),
#  ('tt0000004', Decimal('6.4'), 92),
#  ('tt0000005', Decimal('6.2'), 1565)]

# %% [markdown]
# The structure of a record is as follows:
#
# >tt0000005	6.2	1565
#
#
# Suppose we want to add a record for a title as such:
# >tt0000000 8.2 2000

# %% [markdown]
# We can insert the record as such:

# %%
%%sql
INSERT INTO title_ratings
(tconst, averagerating, numvotes)
VALUES ('tt0000000', 8.2, 2000);
# Out:
#  * postgres://postgres@localhost/imdb2
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# /usr/lib/python3/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1235                     self.dialect.do_execute(
# -> 1236                         cursor, statement, parameters, context
#    1237                     )
#
# /usr/lib/python3/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#
# ForeignKeyViolation: insert or update on table "title_ratings" violates foreign key constraint "tconst_fk_09"
# DETAIL:  Key (tconst)=(tt0000000) is not present in table "title_basics".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-5-ac1cf39799a3> in <module>
# ----> 1 get_ipython().run_cell_magic('sql', '', "INSERT INTO title_ratings\n(tconst, averagerating, numvotes)\nVALUES ('tt0000000', 8.2, 2000);\n")
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2350             with self.builtin_trap:
#    2351                 args = (magic_arg_s, cell)
# -> 2352                 result = fn(*args, **kwargs)
#    2353             return result
#    2354
#
# </usr/local/lib/python3.7/dist-packages/decorator.py:decorator-gen-135> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# </usr/local/lib/python3.7/dist-packages/decorator.py:decorator-gen-134> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#      93
#      94         try:
# ---> 95             result = sql.run.run(conn, parsed['sql'], self, user_ns)
#      96
#      97             if result is not None and not isinstance(result, str) and self.column_local_vars:
#
# /usr/local/lib/python3.7/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     338             else:
#     339                 txt = sqlalchemy.sql.text(statement)
# --> 340                 result = conn.session.execute(txt, user_namespace)
#     341             _commit(conn=conn, config=config)
#     342             if result and config.feedback:
#
# /usr/lib/python3/dist-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     978             raise exc.ObjectNotExecutableError(object_)
#     979         else:
# --> 980             return meth(self, multiparams, params)
#     981
#     982     def _execute_function(self, func, multiparams, params):
#
# /usr/lib/python3/dist-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# /usr/lib/python3/dist-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1097             distilled_params,
#    1098             compiled_sql,
# -> 1099             distilled_params,
#    1100         )
#    1101         if self._has_events or self.engine._has_events:
#
# /usr/lib/python3/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1238         except BaseException as e:
#    1239             self._handle_dbapi_exception(
# -> 1240                 e, statement, parameters, cursor, context
#    1241             )
#    1242
#
# /usr/lib/python3/dist-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1456                 util.raise_from_cause(newraise, exc_info)
#    1457             elif should_wrap:
# -> 1458                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1459             else:
#    1460                 util.reraise(*exc_info)
#
# /usr/lib/python3/dist-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# /usr/lib/python3/dist-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# /usr/lib/python3/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1234                 if not evt_handled:
#    1235                     self.dialect.do_execute(
# -> 1236                         cursor, statement, parameters, context
#    1237                     )
#    1238         except BaseException as e:
#
# /usr/lib/python3/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     534
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#     538     def do_execute_no_params(self, cursor, statement, context=None):
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "title_ratings" violates foreign key constraint "tconst_fk_09"
# DETAIL:  Key (tconst)=(tt0000000) is not present in table "title_basics".
#  [SQL: "INSERT INTO title_ratings\n(tconst, averagerating, numvotes)\nVALUES ('tt0000000', 8.2, 2000);"] (Background on this error at: http://sqlalche.me/e/gkpj)

# %% [markdown]
# Note that we may omit the (tconst, averagerating, numvotes) since we are referring to all columns

# %% [markdown]
# Running the same code again returns an error as:
# ```
# IntegrityError: duplicate key value violates unique constraint "title_ratings_pk"
# DETAIL:  Key (tconst)=(tt0000000) already exists.
# ```

# %% [markdown]
# Now let's check whether the record is added: (we will go over SELECT, FROM, ORDER BY and LIMIT command/clauses later):

# %%
%%sql
SELECT * FROM title_ratings WHERE tconst = 'tt0000000';

# %% [markdown]
# For more info on INSERT command:
#
# https://www.postgresql.org/docs/current/static/sql-insert.html

# %% [markdown]
# ### Update a record

# %% [markdown]
# Now suppose we want to update the record such that averagerating is now 8.7 and numvotes is 3000:

# %%
%%sql
UPDATE title_ratings
SET
averagerating = 8.2,
numvotes = 3000
WHERE tconst = 'tt0000000';
# Out:
#  * postgres://postgres@localhost/imdb2
# 0 rows affected.
# []

# %% [markdown]
# And check whether the record is updated:

# %%
%%sql
SELECT *
FROM title_ratings
WHERE tconst = 'tt0000000';
# Out:
#  * postgres://postgres@localhost/imdb2
# 0 rows affected.
# []

# %% [markdown]
# For more info on the UPDATE command:
#
# https://www.postgresql.org/docs/current/static/sql-update.html

# %% [markdown]
# ### Delete a record

# %% [markdown]
# Now let's delete the record we just added:

# %%
%%sql
DELETE FROM title_ratings
WHERE tconst = 'tt0000000';

# %%
%%sql
SELECT *
FROM title_ratings
WHERE tconst = 'tt0000000';

# %% [markdown]
# To get more info on the delete command:
#
# https://www.postgresql.org/docs/current/static/sql-delete.html

# %% [markdown]
# **EXERCISE 6:**
#
# Into imdb1 database:
# - Insert a record into title_ratings where tconst is tt9999999, and numvotes is 10000
# - Filter for the tconst and print the row
# - Update the same record so that averagerating is 9 and numvotes is 20000
# - Filter for the tconst and print the row
# - Delete the same record
# - Filter for the tconst and see that it does not exist anymore

# %%
psql -U postgres -d imdb1 <<EOF

-- statements here. end each of them with a semicolon

EOF

# %% [markdown]
# **SOLUTION 6:**

# %%
pass1=
encrypt="U2FsdGVkX1/7SgGX1CAiSzJ57xtYsg/bcu4afSsoE7A1y2QiXSbeoPNQ3Odswc9q sn/RNaZozo6geal6To9P04xwqgGwGykq8d+D/QPtR3iog7ie+MV57TP0qaVjBcXe BpU6V/F08Bqjq72vOa5nFjco4m1tOr/WPBbkXN6IF3+Qa9v1C8e/jR46aFG5fhoZ JcXmhq+8776FXLScUosrrLBr7twr6ZY+9RSrUu29UVeiPlcA+AkbVWlDzNP38cmN 0IA6fU8jjOo1rtDhJ9ykmZpdqhJgWrdU1STR/9cdtJcIPA+S4L0/dBfKF+jX/YcA xyTmjCkihJ2Ypj0ZxhN/0HNnfP/xsH97DFOFha8P2gfj73IHioYSExxcD9c0FCuM MmWISXyoY7BkTwL/DAUpiFA0p4zIBXtTivdd2Wa7ngehGJRmM+erMa91QM6GDRC+ s+LooUBHtZo3SwH5TGzuGgS2p6lEkKHOlKPkswi4NJGQh2S1VXgAmhJTx7U/puQN cl7Njp/NRuVaylSu43LYlpbj6Xe9LW6BdR58XrQ/dlQzdvIBYC/CZ7f0vWiFd1c/ dRNQT5eM5Ek83gDCDDvoCRmnSWgQU2SCK0H/jum2ImY0b2GN6uG3J+aI1o5gRDRb /V6jl0DHhulPsi+W/1bPaoNqznrnnw2jL5oIyVCfPcKrgENj4XOYya6sOpUO+ly4 MzXsy/RC5LX9qbo0B7PkNA=="
solution=$(echo $encrypt | openssl enc -md sha256 -aes-128-cbc -a -d -salt -pass pass:$pass1 2> /dev/null)
echo "$solution"; echo
for l in "$solution"; do eval "${l}"; done

# %% [markdown]
# ## Ending exercise

# %% [markdown]
# Now use your imagination and using any of the tables in imdb2 (you can get the details with \dt+ and \d+ public.* from psql/pgcli), create any interesting query of yourself using (single or multiple) joins, (single or multiple) where, group by, having, order, distinct or limit clauses. You can also use subqueries.
#
# But you should first explain in clear English, what your query is meant to do. What is the purpose of your query?
#
# Save your query for future reference. You may need it for a compulsory homework!
#
# Feel free ...
